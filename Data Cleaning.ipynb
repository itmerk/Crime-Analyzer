# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel(r'Sample Crime Dataset.xlsx')

# %%
data.head()
# Out:
#          ID Case Number                Date                      Block IUCR  \
# 0   5741943    HN549294 2007-08-25 09:22:18         074XX N ROGERS AVE  560
# 1     25953    JE240540 2021-05-24 15:06:00        020XX N LARAMIE AVE  110
# 2     26038    JE279849 2021-06-26 09:24:00      062XX N MC CORMICK RD  110
# 3  13279676    JG507211 2023-11-09 07:30:00           019XX W BYRON ST  620
# 4  13274752    JG501049 2023-11-12 07:59:00  086XX S COTTAGE GROVE AVE  454
#
#   Primary Type                                        Description  \
# 0      ASSAULT                                             SIMPLE
# 1     HOMICIDE                                FIRST DEGREE MURDER
# 2     HOMICIDE                                FIRST DEGREE MURDER
# 3     BURGLARY                                     UNLAWFUL ENTRY
# 4      BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    999 non-null    int64
#  1   Case Number           999 non-null    object
#  2   Date                  999 non-null    datetime64[ns]
#  3   Block                 999 non-null    object
#  4   IUCR                  999 non-null    object
#  5   Primary Type          999 non-null    object
#  6   Description           999 non-null    object
#  7   Location Description  997 non-null    object
#  8   Arrest                999 non-null    bool
#  9   Domestic              999 non-null    bool
#  10  Beat                  999 non-null    int64
#  11  District              999 non-null    int64
#  12  Ward                  998 non-null    float64
#  13  Community Area        998 non-null    float64
#  14  FBI Code              999 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# ID                       0
# Case Number              0
# Date                     0
# Block                    0
# IUCR                     0
# Primary Type             0
# Description              0
# Location Description     2
# Arrest                   0
# Domestic                 0
# Beat                     0
# District                 0
# Ward                     1
# Community Area           1
# FBI Code                 0
# X Coordinate            20
# Y Coordinate            20
# Year                     0
# Updated On               0
# Latitude                20
# Longitude               20
# Location                20
# dtype: int64

# %%
df = data.dropna(axis=0)
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#            ID Case Number                Date                      Block  \
# 0       25953    JE240540 2021-05-24 15:06:00        020XX N LARAMIE AVE
# 1       26038    JE279849 2021-06-26 09:24:00      062XX N MC CORMICK RD
# 2    13279676    JG507211 2023-11-09 07:30:00           019XX W BYRON ST
# 3    13274752    JG501049 2023-11-12 07:59:00  086XX S COTTAGE GROVE AVE
# 4    13203321    JG415333 2023-09-06 17:00:00           002XX N Wells st
# ..        ...         ...                 ...                        ...
# 972  13203421    JG415540 2023-09-07 20:24:00         013XX S WABASH AVE
# 973  13202672    JG414584 2023-09-07 00:01:00        071XX S LANGLEY AVE
# 974  13204410    JG416803 2023-09-07 13:34:00            007XX W 72ND ST
# 975  13204809    JG415669 2023-09-07 20:30:00        083XX S BRANDON AVE
# 976  13208800    JG411427 2023-09-05 02:44:00   067XX S STONY ISLAND AVE
#
#      IUCR         Primary Type  \
# 0     110             HOMICIDE
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    977 non-null    int64
#  1   Case Number           977 non-null    object
#  2   Date                  977 non-null    datetime64[ns]
#  3   Block                 977 non-null    object
#  4   IUCR                  977 non-null    object
#  5   Primary Type          977 non-null    object
#  6   Description           977 non-null    object
#  7   Location Description  977 non-null    object
#  8   Arrest                977 non-null    bool
#  9   Domestic              977 non-null    bool
#  10  Beat                  977 non-null    int64
#  11  District              977 non-null    int64
#  12  Ward                  977 non-null    float64
#  13  Community Area        977 non-null    float64
#  14  FBI Code              977 non-null    object
# ...

# %%
df['ID'].nunique()
# Out:
# 977

# %%
df['ID'].unique()
# Out:
# array([   25953,    26038, 13279676, 13274752, 13203321, 13210088,
#        13210004, 13210062, 13210107, 13210060, 13210120, 13210071,
#        13210035, 13210008, 13210072, 13278080, 13272487, 13279067,
#        13276884, 13273309, 13272745, 13272632, 11662417, 12218064,
#        12342615, 12589893, 12592454, 12601676, 12785595, 12808281,
#        12888104, 12990873, 13045102, 13074891, 13099339, 13121127,
#        13124701, 13129199, 13158716, 13176001, 13179181, 13179344,
#        13181797, 13181885, 13183042, 13183567, 13184491, 13187048,
#        13188630, 13189104, 13189895, 13190165, 13190179, 13190936,
#        13190943, 13192516, 13193728, 13194223, 13195102, 13196606,
#        13196922, 13197242, 13197663, 13197901, 13197965, 13198575,
#        13199574, 13199642, 13199696, 13200550, 13200685, 13200930,
#        13201040, 13201167, 13200739,    26262,  7823660, 13208615,
#        13208678, 13208664, 13208665, 13208668, 13208672, 13273606,
# ...

# %%
df['Case Number'].unique()
# Out:
# array(['JE240540', 'JE279849', 'JG507211', 'JG501049', 'JG415333',
#        'JG423627', 'JG422532', 'JG423596', 'JG411849', 'JG423567',
#        'JG423499', 'JG421086', 'JG422370', 'JG422517', 'JG422242',
#        'JG500620', 'JG498648', 'JG506481', 'JG503649', 'JG499633',
#        'JG498891', 'JG498834', 'JC232642', 'JD426642', 'JE202211',
#        'JF109865', 'JF113025', 'JF124024', 'JF346553', 'JF373517',
#        'JF469015', 'JG161829', 'JG226663', 'JG262771', 'JG291745',
#        'JG313964', 'JG321999', 'JG327622', 'JG362691', 'JG382803',
#        'JG386523', 'JG386917', 'JG389859', 'JG389920', 'JG391309',
#        'JG392073', 'JG393031', 'JG395977', 'JG398002', 'JG398575',
#        'JG399264', 'JG399731', 'JG399829', 'JG400683', 'JG400635',
#        'JG402535', 'JG404030', 'JG404599', 'JG405850', 'JG407589',
#        'JG407863', 'JG408409', 'JG408814', 'JG409181', 'JG409253',
#        'JG409922', 'JG411101', 'JG411210', 'JG411222', 'JG412373',
# ...

# %%
df['Case Number'].nunique()
# Out:
# 977

# %%
df['Date'].unique()
# Out:
# <DatetimeArray>
# ['2021-05-24 15:06:00', '2021-06-26 09:24:00', '2023-11-09 07:30:00',
#  '2023-11-12 07:59:00', '2023-09-06 17:00:00', '2023-08-31 12:00:00',
#  '2023-07-24 21:45:00', '2023-08-27 07:00:00', '2023-09-04 21:30:00',
#  '2023-08-15 14:20:00',
#  ...
#  '2023-09-07 00:15:00', '2023-09-07 14:15:00', '2023-09-07 06:35:00',
#  '2023-09-07 01:38:00', '2023-09-07 11:32:00', '2023-09-07 20:24:00',
#  '2023-09-07 00:01:00', '2023-09-07 13:34:00', '2023-09-07 20:30:00',
#  '2023-09-05 02:44:00']
# Length: 626, dtype: datetime64[ns]

# %%
df['Date'].nunique()
# Out:
# 626

# %%
df['Date']
# Out:
# 0     2021-05-24 15:06:00
# 1     2021-06-26 09:24:00
# 2     2023-11-09 07:30:00
# 3     2023-11-12 07:59:00
# 4     2023-09-06 17:00:00
#               ...
# 972   2023-09-07 20:24:00
# 973   2023-09-07 00:01:00
# 974   2023-09-07 13:34:00
# 975   2023-09-07 20:30:00
# 976   2023-09-05 02:44:00
# Name: Date, Length: 977, dtype: datetime64[ns]

# %%
df.loc[:,'Date'] = pd.to_datetime(df['Date'])

# %%
df['Date']
# Out:
# 0     2021-05-24 15:06:00
# 1     2021-06-26 09:24:00
# 2     2023-11-09 07:30:00
# 3     2023-11-12 07:59:00
# 4     2023-09-06 17:00:00
#               ...
# 972   2023-09-07 20:24:00
# 973   2023-09-07 00:01:00
# 974   2023-09-07 13:34:00
# 975   2023-09-07 20:30:00
# 976   2023-09-05 02:44:00
# Name: Date, Length: 977, dtype: datetime64[ns]

# %%
# Example DataFrame
data = {'Date': ['2021-05-24 15:06:00', '2021-06-18 09:30:00', '2021-07-01 18:45:00']}
test = pd.DataFrame(data)

# Convert 'Date' column to datetime format
test['Date'] = pd.to_datetime(test['Date'])

# Extract time and assign it to a new column 'Time'
test['Time'] = test['Date'].dt.time

# Display the updated DataFrame
print(test)
# Out:
#                  Date      Time
# 0 2021-05-24 15:06:00  15:06:00
# 1 2021-06-18 09:30:00  09:30:00
# 2 2021-07-01 18:45:00  18:45:00

# %%
df['Time'] = pd.to_datetime(df['Date'], format='%H:%M:%S').dt.time
df['Time']
# Out:
# 0      15:06:00
# 1      09:24:00
# 2      07:30:00
# 3      07:59:00
# 4      17:00:00
#          ...
# 972    20:24:00
# 973    00:01:00
# 974    13:34:00
# 975    20:30:00
# 976    02:44:00
# Name: Time, Length: 977, dtype: object

# %%
df['Year'] = df['Date'].dt.year
df['Year']
# Out:
# 0      2021
# 1      2021
# 2      2023
# 3      2023
# 4      2023
#        ...
# 972    2023
# 973    2023
# 974    2023
# 975    2023
# 976    2023
# Name: Year, Length: 977, dtype: int32

# %%
df['Month'] = df['Date'].dt.month
df['Month']
# Out:
# 0       5
# 1       6
# 2      11
# 3      11
# 4       9
#        ..
# 972     9
# 973     9
# 974     9
# 975     9
# 976     9
# Name: Month, Length: 977, dtype: int32

# %%
df['Day'] = df['Date'].dt.day
df['Day']
# Out:
# 0      24
# 1      26
# 2       9
# 3      12
# 4       6
#        ..
# 972     7
# 973     7
# 974     7
# 975     7
# 976     5
# Name: Day, Length: 977, dtype: int32

# %%
df['Hour'] = pd.to_datetime(df['Time'],format='%H:%M:%S').dt.hour
df['Hour']
# Out:
# 0      15
# 1       9
# 2       7
# 3       7
# 4      17
#        ..
# 972    20
# 973     0
# 974    13
# 975    20
# 976     2
# Name: Hour, Length: 977, dtype: int32

# %%
df.head()
# Out:
#          ID Case Number                Date                      Block  IUCR  \
# 0     25953    JE240540 2021-05-24 15:06:00        020XX N LARAMIE AVE   110
# 1     26038    JE279849 2021-06-26 09:24:00      062XX N MC CORMICK RD   110
# 2  13279676    JG507211 2023-11-09 07:30:00           019XX W BYRON ST   620
# 3  13274752    JG501049 2023-11-12 07:59:00  086XX S COTTAGE GROVE AVE   454
# 4  13203321    JG415333 2023-09-06 17:00:00           002XX N Wells st  1320
#
#       Primary Type                                        Description  \
# 0         HOMICIDE                                FIRST DEGREE MURDER
# 1         HOMICIDE                                FIRST DEGREE MURDER
# 2         BURGLARY                                     UNLAWFUL ENTRY
# 3          BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
# 4  CRIMINAL DAMAGE                                         TO VEHICLE
#
#                      Location Description  Arrest  Domestic  ...  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location', 'Time', 'Month', 'Day', 'Hour'],
#       dtype='object')

# %%
df.drop(['Date','Location'],axis=1,inplace=True)

# %%
df1 = df.copy()

# %%
df1['Updated On Date'] = pd.to_datetime(df1['Updated On'], format='%H:%M:%S').dt.time
df1['Updated On Date']
# Out:
# 0      15:39:49
# 1      15:39:49
# 2      15:39:49
# 3      15:41:24
# 4      15:40:18
#          ...
# 972    15:42:23
# 973    15:42:23
# 974    15:42:23
# 975    15:42:23
# 976    15:41:25
# Name: Updated On Date, Length: 977, dtype: object

# %%
df1['Updated On Year'] = df1['Updated On'].dt.year
df1['Updated On Year']
# Out:
# 0      2023
# 1      2023
# 2      2023
# 3      2023
# 4      2023
#        ...
# 972    2023
# 973    2023
# 974    2023
# 975    2023
# 976    2023
# Name: Updated On Year, Length: 977, dtype: int32

# %%
df1['Updated On Month'] = df1['Updated On'].dt.month
df1['Updated On Month']
# Out:
# 0      11
# 1      11
# 2      11
# 3      12
# 4      11
#        ..
# 972     9
# 973     9
# 974     9
# 975     9
# 976     9
# Name: Updated On Month, Length: 977, dtype: int32

# %%
df1['Updated On Day'] = df1['Updated On'].dt.day
df1['Updated On Day']
# Out:
# 0      18
# 1      18
# 2      18
# 3       9
# 4       4
#        ..
# 972    15
# 973    15
# 974    15
# 975    15
# 976    15
# Name: Updated On Day, Length: 977, dtype: int32

# %%
df1
# Out:
#            ID Case Number                      Block  IUCR  \
# 0       25953    JE240540        020XX N LARAMIE AVE   110
# 1       26038    JE279849      062XX N MC CORMICK RD   110
# 2    13279676    JG507211           019XX W BYRON ST   620
# 3    13274752    JG501049  086XX S COTTAGE GROVE AVE   454
# 4    13203321    JG415333           002XX N Wells st  1320
# ..        ...         ...                        ...   ...
# 972  13203421    JG415540         013XX S WABASH AVE   820
# 973  13202672    JG414584        071XX S LANGLEY AVE   910
# 974  13204410    JG416803            007XX W 72ND ST  1130
# 975  13204809    JG415669        083XX S BRANDON AVE   486
# 976  13208800    JG411427   067XX S STONY ISLAND AVE  1310
#
#             Primary Type                                        Description  \
# 0               HOMICIDE                                FIRST DEGREE MURDER
# 1               HOMICIDE                                FIRST DEGREE MURDER
# ...

# %%
df1.columns
# Out:
# Index(['ID', 'Case Number', 'Block', 'IUCR', 'Primary Type', 'Description',
#        'Location Description', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'Community Area', 'FBI Code', 'X Coordinate', 'Y Coordinate',
#        'Year', 'Updated On', 'Latitude', 'Longitude', 'Time', 'Month', 'Day',
#        'Hour', 'Updated On Date', 'Updated On Year', 'Updated On Month',
#        'Updated On Day'],
#       dtype='object')

# %%
df1.drop(['Updated On'],axis=1,inplace=True)

# %%
df1
# Out:
#            ID Case Number                      Block  IUCR  \
# 0       25953    JE240540        020XX N LARAMIE AVE   110
# 1       26038    JE279849      062XX N MC CORMICK RD   110
# 2    13279676    JG507211           019XX W BYRON ST   620
# 3    13274752    JG501049  086XX S COTTAGE GROVE AVE   454
# 4    13203321    JG415333           002XX N Wells st  1320
# ..        ...         ...                        ...   ...
# 972  13203421    JG415540         013XX S WABASH AVE   820
# 973  13202672    JG414584        071XX S LANGLEY AVE   910
# 974  13204410    JG416803            007XX W 72ND ST  1130
# 975  13204809    JG415669        083XX S BRANDON AVE   486
# 976  13208800    JG411427   067XX S STONY ISLAND AVE  1310
#
#             Primary Type                                        Description  \
# 0               HOMICIDE                                FIRST DEGREE MURDER
# 1               HOMICIDE                                FIRST DEGREE MURDER
# ...

# %%
file_name = 'Clean Crime Dataset.xlsx'
df1.to_excel(file_name,index=False)

print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
crime_data = df1.copy()

# %%
crime_data.head()
# Out:
#          ID Case Number                      Block  IUCR     Primary Type  \
# 0     25953    JE240540        020XX N LARAMIE AVE   110         HOMICIDE
# 1     26038    JE279849      062XX N MC CORMICK RD   110         HOMICIDE
# 2  13279676    JG507211           019XX W BYRON ST   620         BURGLARY
# 3  13274752    JG501049  086XX S COTTAGE GROVE AVE   454          BATTERY
# 4  13203321    JG415333           002XX N Wells st  1320  CRIMINAL DAMAGE
#
#                                          Description  \
# 0                                FIRST DEGREE MURDER
# 1                                FIRST DEGREE MURDER
# 2                                     UNLAWFUL ENTRY
# 3  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
# 4                                         TO VEHICLE
#
#                      Location Description  Arrest  Domestic  Beat  ...  \
# 0                                  STREET    True     False  2515  ...
# ...
