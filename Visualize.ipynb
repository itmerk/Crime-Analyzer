# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
crime_data = pd.read_excel(r"D:\Data Science\Projects\My Projects\Project 11\Clean Crime Dataset.xlsx")

# %%
crime_data.head()
# Out:
#          ID Case Number                      Block  IUCR     Primary Type  \
# 0     25953    JE240540        020XX N LARAMIE AVE   110         HOMICIDE
# 1     26038    JE279849      062XX N MC CORMICK RD   110         HOMICIDE
# 2  13279676    JG507211           019XX W BYRON ST   620         BURGLARY
# 3  13274752    JG501049  086XX S COTTAGE GROVE AVE   454          BATTERY
# 4  13203321    JG415333           002XX N Wells st  1320  CRIMINAL DAMAGE
#
#                                          Description  \
# 0                                FIRST DEGREE MURDER
# 1                                FIRST DEGREE MURDER
# 2                                     UNLAWFUL ENTRY
# 3  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
# 4                                         TO VEHICLE
#
#                      Location Description  Arrest  Domestic  Beat  ...  \
# 0                                  STREET    True     False  2515  ...
# 1                             PARKING LOT    True     False  1711  ...
# 2                               APARTMENT   False     False  1922  ...
# 3                      SMALL RETAIL STORE    True     False   632  ...
# 4  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False   122  ...
#
#    Longitude      Time  Month Day  Hour  Updated On Time  Updated On Year  \
# 0 -87.755969  15:06:00      5  24    15         15:39:49             2023
# 1 -87.713355  09:24:00      6  26     9         15:39:49             2023
# 2 -87.677975  07:30:00     11   9     7         15:39:49             2023
# 3 -87.604856  07:59:00     11  12     7         15:41:24             2023
# 4 -87.633938  17:00:00      9   6    17         15:40:18             2023
#
#    Updated On Month  Updated On Day  Season
# 0                11              18  Spring
# 1                11              18  Summer
# 2                11              18    Fall
# 3                12               9    Fall
# 4                11               4    Fall
#
# [5 rows x 28 columns]

# %%
crime_data.columns
# Out:
# Index(['ID', 'Case Number', 'Block', 'IUCR', 'Primary Type', 'Description',
#        'Location Description', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'Community Area', 'FBI Code', 'X Coordinate', 'Y Coordinate',
#        'Year', 'Latitude', 'Longitude', 'Time', 'Month', 'Day', 'Hour',
#        'Updated On Time', 'Updated On Year', 'Updated On Month',
#        'Updated On Day', 'Season'],
#       dtype='object')

# %%
crime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    977 non-null    int64
#  1   Case Number           977 non-null    object
#  2   Block                 977 non-null    object
#  3   IUCR                  977 non-null    object
#  4   Primary Type          977 non-null    object
#  5   Description           977 non-null    object
#  6   Location Description  977 non-null    object
#  7   Arrest                977 non-null    bool
#  8   Domestic              977 non-null    bool
#  9   Beat                  977 non-null    int64
#  10  District              977 non-null    int64
#  11  Ward                  977 non-null    int64
#  12  Community Area        977 non-null    int64
#  13  FBI Code              977 non-null    object
#  14  X Coordinate          977 non-null    int64
#  15  Y Coordinate          977 non-null    int64
#  16  Year                  977 non-null    int64
#  17  Latitude              977 non-null    float64
#  18  Longitude             977 non-null    float64
#  19  Time                  977 non-null    object
#  20  Month                 977 non-null    int64
#  21  Day                   977 non-null    int64
#  22  Hour                  977 non-null    int64
#  23  Updated On Time       977 non-null    object
#  24  Updated On Year       977 non-null    int64
#  25  Updated On Month      977 non-null    int64
#  26  Updated On Day        977 non-null    int64
#  27  Season                977 non-null    object
# dtypes: bool(2), float64(2), int64(14), object(10)
# memory usage: 200.5+ KB

# %%
crime_data.isnull().sum()
# Out:
# ID                      0
# Case Number             0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Year                    0
# Latitude                0
# Longitude               0
# Time                    0
# Month                   0
# Day                     0
# Hour                    0
# Updated On Time         0
# Updated On Year         0
# Updated On Month        0
# Updated On Day          0
# Season                  0
# dtype: int64

# %% [markdown]
# ## Crime Trends Over Time:
#
# Examine how the number of crimes has changed over the years. This could include plotting the number of crimes per year, month, or even day to identify trends or seasonal variations.

# %%
crime_data['Year']
# Out:
# 0      2021
# 1      2021
# 2      2023
# 3      2023
# 4      2023
#        ...
# 972    2023
# 973    2023
# 974    2023
# 975    2023
# 976    2023
# Name: Year, Length: 977, dtype: int64

# %%
crime_data['Year'].unique()
# Out:
# array([2021, 2023, 2019, 2020, 2022, 2018, 2010], dtype=int64)

# %%
# Count crimes per year
crime_counts_by_year = crime_data['Year'].value_counts().sort_index()

# Plotting the trend
plt.figure(figsize=(10, 6))
plt.plot(crime_counts_by_year.index, crime_counts_by_year.values, marker='o', linestyle='-')
plt.title('Number of Crimes Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Crimes')
plt.grid(True)
plt.xticks(crime_counts_by_year.index)
plt.tight_layout()
plt.show()

# %%
crime_data['Year'] == 2023
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 972     True
# 973     True
# 974     True
# 975     True
# 976     True
# Name: Year, Length: 977, dtype: bool

# %%
year = crime_data[crime_data['Year'] == 2023]
year
# Out:
#            ID Case Number                      Block  IUCR  \
# 2    13279676    JG507211           019XX W BYRON ST   620
# 3    13274752    JG501049  086XX S COTTAGE GROVE AVE   454
# 4    13203321    JG415333           002XX N Wells st  1320
# 5    13210088    JG423627       023XX W JACKSON BLVD  1153
# 6    13210004    JG422532       073XX S JEFFERY BLVD   281
# ..        ...         ...                        ...   ...
# 972  13203421    JG415540         013XX S WABASH AVE   820
# 973  13202672    JG414584        071XX S LANGLEY AVE   910
# 974  13204410    JG416803            007XX W 72ND ST  1130
# 975  13204809    JG415669        083XX S BRANDON AVE   486
# 976  13208800    JG411427   067XX S STONY ISLAND AVE  1310
#
#                 Primary Type  \
# 2                   BURGLARY
# 3                    BATTERY
# 4            CRIMINAL DAMAGE
# 5         DECEPTIVE PRACTICE
# 6    CRIMINAL SEXUAL ASSAULT
# ..                       ...
# 972                    THEFT
# 973      MOTOR VEHICLE THEFT
# 974       DECEPTIVE PRACTICE
# 975                  BATTERY
# 976          CRIMINAL DAMAGE
#
#                                            Description  \
# 2                                       UNLAWFUL ENTRY
# 3    AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
# 4                                           TO VEHICLE
# 5                  FINANCIAL IDENTITY THEFT OVER $ 300
# 6                                       NON-AGGRAVATED
# ..                                                 ...
# 972                                     $500 AND UNDER
# 973                                         AUTOMOBILE
# 974                           FRAUD OR CONFIDENCE GAME
# 975                            DOMESTIC BATTERY SIMPLE
# 976                                        TO PROPERTY
#
#                        Location Description  Arrest  Domestic  Beat  ...  \
# 2                                 APARTMENT   False     False  1922  ...
# 3                        SMALL RETAIL STORE    True     False   632  ...
# 4    PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False   122  ...
# 5                                    STREET   False     False  1225  ...
# 6                                 APARTMENT   False     False   333  ...
# ..                                      ...     ...       ...   ...  ...
# 972                                   ALLEY   False     False   131  ...
# 973                                  STREET   False     False   323  ...
# 974                               RESIDENCE   False     False   732  ...
# 975                               APARTMENT   False      True   424  ...
# 976                              RESTAURANT   False     False   332  ...
#
#      Longitude      Time  Month Day  Hour  Updated On Time  Updated On Year  \
# 2   -87.677975  07:30:00     11   9     7         15:39:49             2023
# 3   -87.604856  07:59:00     11  12     7         15:41:24             2023
# 4   -87.633938  17:00:00      9   6    17         15:40:18             2023
# 5   -87.684791  12:00:00      8  31    12         15:41:56             2023
# 6   -87.576209  21:45:00      7  24    21         15:41:56             2023
# ..         ...       ...    ...  ..   ...              ...              ...
# 972 -87.625786  20:24:00      9   7    20         15:42:23             2023
# 973 -87.607989  00:01:00      9   7     0         15:42:23             2023
# 974 -87.643595  13:34:00      9   7    13         15:42:23             2023
# 975 -87.546672  20:30:00      9   7    20         15:42:23             2023
# 976 -87.586296  02:44:00      9   5     2         15:41:25             2023
#
#      Updated On Month  Updated On Day  Season
# 2                  11              18    Fall
# 3                  12               9    Fall
# 4                  11               4    Fall
# 5                   9              16  Summer
# 6                   9              16  Summer
# ..                ...             ...     ...
# 972                 9              15    Fall
# 973                 9              15    Fall
# 974                 9              15    Fall
# 975                 9              15    Fall
# 976                 9              15    Fall
#
# [949 rows x 28 columns]

# %%
year = crime_data[(crime_data['Year'] == 2023) & (crime_data['Month'] == 11)]
year
# Out:
#            ID Case Number                      Block  IUCR  \
# 2    13279676    JG507211           019XX W BYRON ST   620
# 3    13274752    JG501049  086XX S COTTAGE GROVE AVE   454
# 15   13278080    JG500620         038XX W MADISON ST   910
# 16   13272487    JG498648         019XX N AUSTIN AVE   810
# 17   13279067    JG506481           006XX W GRACE ST  1156
# 18   13276884    JG503649       043XX W AUGUSTA BLVD   910
# 19   13273309    JG499633           107XX S AVENUE H   910
# 20   13272745    JG498891      009XX N FRANCISCO AVE  031A
# 21   13272632    JG498834           010XX W 103RD PL   560
# 83   13273606    JG499982   061XX N CENTRAL PARK AVE   920
# 84   13273283    JG499555            003XX W 64TH ST  1220
# 86   13273264    JG499488          009XX W ARGYLE ST   420
# 87   13276735    JG503576            034XX W 47TH ST   810
# 88   13273042    JG499379            035XX W 78TH ST   486
# 89   13273800    JG499340        012XX S WESTERN AVE  1320
# 90   13273565    JG499918          015XX W SCHOOL ST  1310
# 91   13273013    JG499374     072XX S DORCHESTER AVE  1320
# 92   13274437    JG500138   047XX W BELLE PLAINE AVE   486
# 93   13272562    JG498602             004XX W ELM ST   560
# 95   13280139    JG507723           009XX E 100TH PL   890
# 829  13273619    JG500000        0000X W RANDOLPH ST   820
# 873  13273289    JG499433      078XX S RIDGELAND AVE  1020
# 874  13273367    JG499630         042XX W GLADYS AVE   486
# 875  13272848    JG499075      014XX W EDGEWATER AVE   820
# 876  13273875    JG500326          081XX S EVANS AVE   910
# 877  13275243    JG501831         030XX S POPLAR AVE   810
# 878  13272687    JG498877         023XX S SAWYER AVE  1320
# 879  13272966    JG499231       015XX N CLYBOURN AVE   486
# 880  13273112    JG498789            039XX W 47TH ST  1310
# 881  13273217    JG499397         023XX W MADISON ST   820
# 882     27854    JG499502      076XX N GREENVIEW AVE   110
# 883  13272322    JG498403        049XX W MAYPOLE AVE  031A
# 884  13273512    JG499834          019XX N SAYRE AVE   920
# 885  13272700    JG498857         103XX S DOTY AVE E   930
# 886  13273040    JG499378         051XX S KEDZIE AVE   460
# 887  13273328    JG499637        052XX N SHERIDAN RD   460
# 888  13273474    JG499713           004XX N STATE ST   820
# 889  13278982    JG506361          092XX S CLYDE AVE   930
#
#             Primary Type                                        Description  \
# 2               BURGLARY                                     UNLAWFUL ENTRY
# 3                BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
# 15   MOTOR VEHICLE THEFT                                         AUTOMOBILE
# 16                 THEFT                                          OVER $500
# 17    DECEPTIVE PRACTICE                 ATTEMPT - FINANCIAL IDENTITY THEFT
# 18   MOTOR VEHICLE THEFT                                         AUTOMOBILE
# 19   MOTOR VEHICLE THEFT                                         AUTOMOBILE
# 20               ROBBERY                                    ARMED - HANDGUN
# 21               ASSAULT                                             SIMPLE
# 83   MOTOR VEHICLE THEFT                               ATTEMPT - AUTOMOBILE
# 84    DECEPTIVE PRACTICE                   THEFT OF LOST / MISLAID PROPERTY
# 86               BATTERY            AGGRAVATED - KNIFE / CUTTING INSTRUMENT
# 87                 THEFT                                          OVER $500
# 88               BATTERY                            DOMESTIC BATTERY SIMPLE
# 89       CRIMINAL DAMAGE                                         TO VEHICLE
# 90       CRIMINAL DAMAGE                                        TO PROPERTY
# 91       CRIMINAL DAMAGE                                         TO VEHICLE
# 92               BATTERY                            DOMESTIC BATTERY SIMPLE
# 93               ASSAULT                                             SIMPLE
# 95                 THEFT                                      FROM BUILDING
# 829                THEFT                                     $500 AND UNDER
# 873                ARSON                                            BY FIRE
# 874              BATTERY                            DOMESTIC BATTERY SIMPLE
# 875                THEFT                                     $500 AND UNDER
# 876  MOTOR VEHICLE THEFT                                         AUTOMOBILE
# 877                THEFT                                          OVER $500
# 878      CRIMINAL DAMAGE                                         TO VEHICLE
# 879              BATTERY                            DOMESTIC BATTERY SIMPLE
# 880      CRIMINAL DAMAGE                                        TO PROPERTY
# 881                THEFT                                     $500 AND UNDER
# 882             HOMICIDE                                FIRST DEGREE MURDER
# 883              ROBBERY                                    ARMED - HANDGUN
# 884  MOTOR VEHICLE THEFT                               ATTEMPT - AUTOMOBILE
# 885  MOTOR VEHICLE THEFT                      THEFT / RECOVERY - AUTOMOBILE
# 886              BATTERY                                             SIMPLE
# 887              BATTERY                                             SIMPLE
# 888                THEFT                                     $500 AND UNDER
# 889  MOTOR VEHICLE THEFT                      THEFT / RECOVERY - AUTOMOBILE
#
#                        Location Description  Arrest  Domestic  Beat  ...  \
# 2                                 APARTMENT   False     False  1922  ...
# 3                        SMALL RETAIL STORE    True     False   632  ...
# 15                                   STREET   False     False  1122  ...
# 16   PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False  2513  ...
# 17                                APARTMENT   False     False  1925  ...
# 18                                   STREET   False     False  1111  ...
# 19                                   STREET   False     False   432  ...
# 20                                   STREET   False     False  1211  ...
# 21                                APARTMENT   False      True  2232  ...
# 83                                   STREET   False     False  1711  ...
# 84              HOSPITAL BUILDING / GROUNDS   False     False   722  ...
# 86                                APARTMENT   False     False  2024  ...
# 87             COMMERCIAL / BUSINESS OFFICE   False     False   821  ...
# 88                                RESIDENCE   False      True   835  ...
# 89                                   STREET   False      True  1233  ...
# 90              RESIDENCE - PORCH / HALLWAY   False     False  1922  ...
# 91                                   STREET   False     False   324  ...
# 92                                 SIDEWALK   False      True  1722  ...
# 93                                RESIDENCE   False      True  1823  ...
# 95                                APARTMENT   False     False   511  ...
# 829  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False   111  ...
# 873                               APARTMENT   False     False   414  ...
# 874                               APARTMENT   False      True  1132  ...
# 875                                  STREET   False     False  2013  ...
# 876                                  STREET   False     False   631  ...
# 877                      RESIDENCE - GARAGE   False     False   913  ...
# 878                                  STREET   False     False  1024  ...
# 879                      GROCERY FOOD STORE   False      True  1822  ...
# 880                              DRUG STORE   False     False   821  ...
# 881                              DRUG STORE   False     False  1223  ...
# 882                                  STREET   False     False  2422  ...
# 883                                SIDEWALK   False     False  1532  ...
# 884                                  STREET   False     False  2513  ...
# 885                         OTHER (SPECIFY)   False     False   434  ...
# 886                      GROCERY FOOD STORE   False     False   923  ...
# 887                               APARTMENT   False     False  2023  ...
# 888  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False  1834  ...
# 889                                   ALLEY   False     False   413  ...
#
#      Longitude      Time  Month Day  Hour  Updated On Time  Updated On Year  \
# 2   -87.677975  07:30:00     11   9     7         15:39:49             2023
# 3   -87.604856  07:59:00     11  12     7         15:41:24             2023
# 15  -87.721377  00:00:00     11  11     0         15:40:25             2023
# 16  -87.775425  05:30:00     11  10     5         15:40:25             2023
# 17  -87.646282  12:00:00     11   3    12         15:39:49             2023
# 18  -87.734196  17:30:00     11  10    17         15:40:25             2023
# 19  -87.532866  20:28:00     11  10    20         15:40:25             2023
# 20  -87.699242  12:15:00     11  10    12         15:40:25             2023
# 21  -87.648373  11:00:00     11  10    11         15:40:25             2023
# 83  -87.718933  22:30:00     11  10    22         15:40:25             2023
# 84  -87.633829  03:40:00     11  10     3         15:40:25             2023
# 86  -87.653132  19:54:00     11  10    19         15:40:25             2023
# 87  -87.709103  14:30:00     11  10    14         15:40:25             2023
# 88  -87.710887  18:30:00     11  10    18         15:40:25             2023
# 89  -87.686026  18:00:00     11  10    18         15:40:25             2023
# 90  -87.667566  21:00:00     11  10    21         15:40:25             2023
# 91  -87.590930  18:30:00     11  10    18         15:40:25             2023
# 92  -87.746674  16:30:00     11  10    16         15:40:25             2023
# 93  -87.640640  03:00:00     11  10     3         15:40:25             2023
# 95  -87.599842  12:01:00     11  10    12         15:40:38             2023
# 829 -87.628784  18:00:00     11  10    18         15:40:25             2023
# 873 -87.582121  19:20:00     11  10    19         15:40:25             2023
# 874 -87.731057  23:00:00     11  10    23         15:40:25             2023
# 875 -87.666154  13:00:00     11  10    13         15:40:25             2023
# 876 -87.606333  21:00:00     11  10    21         15:40:25             2023
# 877 -87.647918  18:00:00     11  10    18         15:40:25             2023
# 878 -87.706395  01:00:00     11  10     1         15:40:25             2023
# 879 -87.646657  16:28:00     11  10    16         15:40:25             2023
# 880 -87.722790  01:57:00     11  10     1         15:40:25             2023
# 881 -87.685081  19:00:00     11  10    19         15:40:25             2023
# 882 -87.668243  21:26:00     11  10    21         15:40:25             2023
# 883 -87.749653  01:00:00     11  10     1         15:40:25             2023
# 884 -87.800469  20:00:00     11  10    20         15:40:25             2023
# 885 -87.580709  12:57:00     11  10    12         15:40:25             2023
# 886 -87.703740  18:50:00     11  10    18         15:40:25             2023
# 887 -87.655010  22:30:00     11  10    22         15:40:25             2023
# 888 -87.627995  16:30:00     11  10    16         15:40:25             2023
# 889 -87.573042  22:00:00     11  10    22         15:40:25             2023
#
#      Updated On Month  Updated On Day Season
# 2                  11              18   Fall
# 3                  12               9   Fall
# 15                 11              18   Fall
# 16                 11              18   Fall
# 17                 11              18   Fall
# 18                 11              18   Fall
# 19                 11              18   Fall
# 20                 11              18   Fall
# 21                 11              18   Fall
# 83                 11              18   Fall
# 84                 11              18   Fall
# 86                 11              18   Fall
# 87                 11              18   Fall
# 88                 11              18   Fall
# 89                 11              18   Fall
# 90                 11              18   Fall
# 91                 11              18   Fall
# 92                 11              18   Fall
# 93                 11              18   Fall
# 95                 11              19   Fall
# 829                11              18   Fall
# 873                11              18   Fall
# 874                11              18   Fall
# 875                11              18   Fall
# 876                11              18   Fall
# 877                11              18   Fall
# 878                11              18   Fall
# 879                11              18   Fall
# 880                11              18   Fall
# 881                11              18   Fall
# 882                11              18   Fall
# 883                11              18   Fall
# 884                11              18   Fall
# 885                11              18   Fall
# 886                11              18   Fall
# 887                11              18   Fall
# 888                11              18   Fall
# 889                11              18   Fall
#
# [38 rows x 28 columns]

# %%
# Count crimes per year
crime_counts_by_month= crime_data['Month'].value_counts().sort_index()

# Plotting the trend
plt.figure(figsize=(10, 6))
plt.plot(crime_counts_by_month.index, crime_counts_by_month.values, marker='o', linestyle='-')
plt.title('Number of Crimes Over the Months')
plt.xlabel('Month')
plt.ylabel('Number of Crimes')
plt.grid(True)
plt.xticks(crime_counts_by_month.index)
plt.tight_layout()
plt.show()

# %%
# Count crimes per year
crime_counts_by_day = crime_data['Day'].value_counts().sort_index()

# Plotting the trend
plt.figure(figsize=(10, 6))
plt.plot(crime_counts_by_day.index, crime_counts_by_day.values, marker='o', linestyle='-')
plt.title('Number of Crimes Over the Days')
plt.xlabel('Day')
plt.ylabel('Number of Crimes')
plt.grid(True)
plt.xticks(crime_counts_by_day.index)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Peak Crime Hours:
#
# Determine the times of day when crimes are most frequently reported by analyzing the 'Date' and 'Time' fields

# %%
crime_data['Day']
# Out:
# 0      24
# 1      26
# 2       9
# 3      12
# 4       6
#        ..
# 972     7
# 973     7
# 974     7
# 975     7
# 976     5
# Name: Day, Length: 977, dtype: int64

# %%
crime_per_hour = crime_data['Hour'].value_counts().sort_index()

# Plotting the trend
plt.figure(figsize=(10, 6))
plt.plot(crime_per_hour.index, crime_per_hour.values, marker='o', linestyle='-')
plt.title('Number of Crimes Over the Hours')
plt.xlabel('Year')
plt.ylabel('Number of Crimes')
plt.grid(True)
plt.xticks(crime_per_hour.index)
plt.tight_layout()
plt.show()

# %%
crime_data.columns
# Out:
# Index(['ID', 'Case Number', 'Block', 'IUCR', 'Primary Type', 'Description',
#        'Location Description', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'Community Area', 'FBI Code', 'X Coordinate', 'Y Coordinate',
#        'Year', 'Latitude', 'Longitude', 'Time', 'Month', 'Day', 'Hour',
#        'Updated On Time', 'Updated On Year', 'Updated On Month',
#        'Updated On Day', 'Season'],
#       dtype='object')

# %% [markdown]
# ## Crime Hotspots:
#
# Use the latitude and longitude coordinates to identify areas with high concentrations of crimes. Tools like heatmaps or kernel density estimation can be useful.

# %%
import folium
from folium.plugins import HeatMap
import os

# %% [markdown]
# ## Heatmap

# %%
map_center = [crime_data['Latitude'].mean(),crime_data['Longitude'].mean()]
crime_map = folium.Map(location=map_center,zoom_start=12)

heat_data = [[row['Latitude'],row['Longitude']] for index, row in crime_data.iterrows()]
HeatMap(heat_data).add_to(crime_map)

output_dir = './'
output_path = os.path.join(output_dir, 'crime_heatmap.html')

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Save the map to an HTML file
crime_map.save(output_path)

crime_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_507499853d75799912bc37a2a8740d90 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_507499853d75799912bc37a2a8740d90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_507499853d75799912bc37a2a8740d90 = L.map(
#                 &quot;map_507499853d75799912bc37a2a8740d90&quot;,
#                 {
#                     center: [41.84786522947902, -87.667696123653],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b28815cdbdde0ff0ba33373e00773ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1b28815cdbdde0ff0ba33373e00773ca.addTo(map_507499853d75799912bc37a2a8740d90);
#
#
#             var heat_map_d1918cfe249b2058da751f650b8992db = L.heatLayer(
#                 [[41.917838056, -87.755968972], [41.995219444, -87.713354912], [41.952345086, -87.677975059], [41.737750767, -87.604855911], [41.886018055, -87.633937881], [41.877565108, -87.68479102], [41.7619185, -87.576209245], [41.943378528, -87.7199738], [41.796477414, -87.708540915], [41.752688801, -87.704908791], [41.758126171, -87.631582508], [41.731497731, -87.658074565], [41.764827083, -87.671709119], [41.837651929, -87.641404086], [41.880594385, -87.702959421], [41.880779076, -87.721377025], [41.915187259, -87.775425225], [41.952036311, -87.646281883], [41.898884591, -87.734196199], [41.699971107, -87.532866422], [41.89850206, -87.69924242], [41.705956552, -87.648373487], [41.749500329, -87.6011574], [41.745882542, -87.597167639], [41.746626309, -87.618031954], [41.736409029, -87.562410309], [41.771782439, -87.649436929], [41.899206068, -87.705505587], [41.763337967, -87.597001131], [41.985875279, -87.766403857], [41.76261474, -87.652840463], [41.89621515, -87.728572048], [41.748653803, -87.602680492], [41.932015426, -87.769916668], [41.917562778, -87.749828117], [41.91065261, -87.66614577], [41.692833841, -87.60431945], [41.80890316, -87.618139193], [41.911574252, -87.789972279], [41.788264552, -87.62229949], [41.917656022, -87.688750258], [41.935883156, -87.716219645], [41.917790125, -87.754624625], [41.917506742, -87.753392641], [41.910962378, -87.694559852], [41.921207741, -87.754832585], [41.929743818, -87.684273777], [41.903304304, -87.670064675], [41.924248302, -87.745636923], [41.972359593, -87.728142793], [41.969229299, -87.713386363], [41.928235818, -87.682084152], [41.910107045, -87.707676543], [41.761701305, -87.718642841], [41.9301323, -87.785676799], [41.906519104, -87.758359629], [41.929743818, -87.684273777], [41.928869943, -87.725672915], [41.926287021, -87.785547998], [41.903125362, -87.680983903], [41.748232929, -87.641533277], [41.909687183, -87.796009633], [41.71286177, -87.537694886], [41.910491438, -87.749936608], [41.763423571, -87.705236576], [41.98142637, -87.772997369], [41.796510344, -87.708540596], [41.945583621, -87.747047365], [41.961202055, -87.777049892], [41.988962585, -87.782770866], [41.915389329, -87.765701742], [41.91943601, -87.775564587], [41.902562633, -87.750879383], [41.910505437, -87.676316472], [41.862914501, -87.709737438], [41.873191445, -87.743446563], [41.755353249, -87.651440192], [41.965906449, -87.708395773], [41.807145524, -87.741921764], [41.803995088, -87.741389571], [41.654834273, -87.607558429], [41.807646537, -87.741157889], [41.752935445, -87.5490632], [41.992785149, -87.71893317], [41.778099133, -87.633828531], [41.774140355, -87.599707766], [41.973339203, -87.653132052], [41.80805312, -87.709103358], [41.751497379, -87.710886632], [41.866147762, -87.68602617], [41.941544345, -87.667566063], [41.763740729, -87.590930221], [41.955482844, -87.74667356], [41.902691497, -87.640639866], [41.75953427, -87.60907381], [41.711760405, -87.599842499], [41.907130946, -87.694473144], [41.818970326, -87.642544391], [41.746431352, -87.646345733], [41.760296965, -87.684345797], [41.779881706, -87.636789913], [41.853058663, -87.650190508], [41.843879386, -87.620432585], [41.858686589, -87.631890095], [41.935409279, -87.74675098], [41.968462532, -87.707613294], [41.96607814, -87.647153241], [41.736277091, -87.585212192], [41.763659945, -87.626863438], [41.891943951, -87.768770463], [41.748776618, -87.605167356], [41.769925563, -87.637267875], [41.913472752, -87.764370362], [41.809803372, -87.64556634], [41.98715762, -87.668356321], [41.806060798, -87.590999348], [41.939051438, -87.730438917], [42.013787643, -87.673182834], [42.000299008, -87.807981016], [41.768891175, -87.614133593], [41.872963554, -87.753663295], [41.880414105, -87.72811149], [41.702027818, -87.563981957], [41.902642474, -87.728111001], [41.805309638, -87.58899806], [41.887771177, -87.644304667], [41.973922349, -87.67934257]

# %%
crime_data.columns
# Out:
# Index(['ID', 'Case Number', 'Block', 'IUCR', 'Primary Type', 'Description',
#        'Location Description', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'Community Area', 'FBI Code', 'X Coordinate', 'Y Coordinate',
#        'Year', 'Latitude', 'Longitude', 'Time', 'Month', 'Day', 'Hour',
#        'Updated On Time', 'Updated On Year', 'Updated On Month',
#        'Updated On Day', 'Season'],
#       dtype='object')

# %% [markdown]
# ## District/Ward Analysis:
#
# Compare crime rates across different districts and wards to identify which areas are more prone to specific types of crimes.

# %%
crime_data['District']
# Out:
# 0      25
# 1      17
# 2      19
# 3       6
# 4       1
#        ..
# 972     1
# 973     3
# 974     7
# 975     4
# 976     3
# Name: District, Length: 977, dtype: int64

# %%
crime_data['District'].unique()
# Out:
# array([25, 17, 19,  6,  1, 12,  3,  8,  7, 22,  9, 11,  4, 16, 14,  5,  2,
#        10, 20, 18, 15, 24], dtype=int64)

# %%
crime_data['District'].nunique()
# Out:
# 22

# %%
crime_data['Ward']
# Out:
# 0      36
# 1      50
# 2      47
# 3       6
# 4      42
#        ..
# 972     3
# 973     6
# 974     6
# 975    10
# 976     5
# Name: Ward, Length: 977, dtype: int64

# %%
crime_data['Ward'].unique()
# Out:
# array([36, 50, 47,  6, 42, 27,  7, 30, 14, 18, 21, 17, 11, 28, 29, 46, 37,
#        10, 26,  8, 16,  5, 39,  1,  9,  3, 20, 35, 32, 31, 33, 23, 45, 38,
#        24, 22, 48, 25,  4, 15, 49, 41, 34, 40, 19, 12, 43, 13, 44,  2],
#       dtype=int64)

# %%
crime_data['Ward'].nunique()
# Out:
# 50

# %%
crime_data['Primary Type']
# Out:
# 0                 HOMICIDE
# 1                 HOMICIDE
# 2                 BURGLARY
# 3                  BATTERY
# 4          CRIMINAL DAMAGE
#               ...
# 972                  THEFT
# 973    MOTOR VEHICLE THEFT
# 974     DECEPTIVE PRACTICE
# 975                BATTERY
# 976        CRIMINAL DAMAGE
# Name: Primary Type, Length: 977, dtype: object

# %%
crime_data['Primary Type'].unique()
# Out:
# array(['HOMICIDE', 'BURGLARY', 'BATTERY', 'CRIMINAL DAMAGE',
#        'DECEPTIVE PRACTICE', 'CRIMINAL SEXUAL ASSAULT', 'THEFT',
#        'OFFENSE INVOLVING CHILDREN', 'MOTOR VEHICLE THEFT', 'ROBBERY',
#        'ASSAULT', 'SEX OFFENSE', 'OTHER OFFENSE', 'WEAPONS VIOLATION',
#        'STALKING', 'CRIMINAL TRESPASS', 'PROSTITUTION', 'ARSON',
#        'NARCOTICS', 'KIDNAPPING', 'CONCEALED CARRY LICENSE VIOLATION',
#        'INTERFERENCE WITH PUBLIC OFFICER', 'PUBLIC PEACE VIOLATION'],
#       dtype=object)

# %%
crime_data['Primary Type'].nunique()
# Out:
# 23

# %%
# Group by District and Primary Type to count crimes
district_crime_counts = crime_data.groupby(['District', 'Primary Type']).size().unstack(fill_value=0)

# Group by Ward and Primary Type to count crimes
ward_crime_counts = crime_data.groupby(['Ward', 'Primary Type']).size().unstack(fill_value=0)

# Plotting for Districts
district_crime_counts.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Crime Types Across Districts')
plt.xlabel('District')
plt.ylabel('Number of Crimes')
plt.legend(title='Crime Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Plotting for Wards
ward_crime_counts.plot(kind='bar', stacked=True, figsize=(25, 8))
plt.title('Crime Types Across Wards')
plt.xlabel('Ward')
plt.ylabel('Number of Crimes')
plt.legend(title='Crime Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Distribution of Crime Types:
#
# Analyze the frequency of different 'Primary Type' and 'Description' fields to understand the most common types of crimes.

# %%
crime_data['Primary Type'].unique()
# Out:
# array(['HOMICIDE', 'BURGLARY', 'BATTERY', 'CRIMINAL DAMAGE',
#        'DECEPTIVE PRACTICE', 'CRIMINAL SEXUAL ASSAULT', 'THEFT',
#        'OFFENSE INVOLVING CHILDREN', 'MOTOR VEHICLE THEFT', 'ROBBERY',
#        'ASSAULT', 'SEX OFFENSE', 'OTHER OFFENSE', 'WEAPONS VIOLATION',
#        'STALKING', 'CRIMINAL TRESPASS', 'PROSTITUTION', 'ARSON',
#        'NARCOTICS', 'KIDNAPPING', 'CONCEALED CARRY LICENSE VIOLATION',
#        'INTERFERENCE WITH PUBLIC OFFICER', 'PUBLIC PEACE VIOLATION'],
#       dtype=object)

# %%
# Count frequencies of each crime type ('Primary Type')
crime_type_counts = crime_data['Primary Type'].value_counts()

# Optionally, count frequencies of each crime description ('Description')
crime_description_counts = crime_data['Description'].value_counts().head(25)

# Plotting the distribution of crime types
plt.figure(figsize=(12, 8))
crime_type_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Crime Types')
plt.xlabel('Crime Type')
plt.ylabel('Number of Crimes')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

#Optionally, plot the distribution of crime descriptions
plt.figure(figsize=(12, 8))
crime_description_counts.plot(kind='bar', color='lightcoral')
plt.title('Distribution of Crime Descriptions')
plt.xlabel('Crime Description')
plt.ylabel('Number of Crimes')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Severity Analysis:
#
# Investigate the distribution of severe crimes (e.g., homicides, assaults) versus less severe crimes (e.g., thefts, fraud).

# %%
crime_data.columns
# Out:
# Index(['ID', 'Case Number', 'Block', 'IUCR', 'Primary Type', 'Description',
#        'Location Description', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'Community Area', 'FBI Code', 'X Coordinate', 'Y Coordinate',
#        'Year', 'Latitude', 'Longitude', 'Time', 'Month', 'Day', 'Hour',
#        'Updated On Time', 'Updated On Year', 'Updated On Month',
#        'Updated On Day', 'Season'],
#       dtype='object')

# %%
crime_data['Primary Type'].unique()
# Out:
# array(['HOMICIDE', 'BURGLARY', 'BATTERY', 'CRIMINAL DAMAGE',
#        'DECEPTIVE PRACTICE', 'CRIMINAL SEXUAL ASSAULT', 'THEFT',
#        'OFFENSE INVOLVING CHILDREN', 'MOTOR VEHICLE THEFT', 'ROBBERY',
#        'ASSAULT', 'SEX OFFENSE', 'OTHER OFFENSE', 'WEAPONS VIOLATION',
#        'STALKING', 'CRIMINAL TRESPASS', 'PROSTITUTION', 'ARSON',
#        'NARCOTICS', 'KIDNAPPING', 'CONCEALED CARRY LICENSE VIOLATION',
#        'INTERFERENCE WITH PUBLIC OFFICER', 'PUBLIC PEACE VIOLATION'],
#       dtype=object)

# %%
import numpy as np

# %%
# Assuming your dataset is loaded into a DataFrame called crime_data
# Ensure 'Primary Type' field exists in your dataset

# Define severity categories based on crime types
severe_crimes = ['HOMICIDE', 'ASSAULT', 'CRIMINAL SEXUAL ASSAULT', 'ROBBERY']
less_severe_crimes = ['THEFT', 'BURGLARY', 'FRAUD', 'MOTOR VEHICLE THEFT']

# Create a new column 'Crime Severity' based on the defined categories
crime_data['Crime Severity'] = np.where(crime_data['Primary Type'].isin(severe_crimes), 'Severe', 'Less Severe')

# Count frequencies of each severity category
severity_counts = crime_data['Crime Severity'].value_counts()

# Plotting the distribution of crime severity
plt.figure(figsize=(8, 6))
severity_counts.plot(kind='bar', color=['red', 'blue'])
plt.title('Distribution of Crime Severity')
plt.xlabel('Crime Severity')
plt.ylabel('Number of Crimes')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Arrest Rates:
#
# Calculate the percentage of crimes that result in an arrest. This can be broken down by crime type, location, and time period.

# %%
crime_data.columns
# Out:
# Index(['ID', 'Case Number', 'Block', 'IUCR', 'Primary Type', 'Description',
#        'Location Description', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'Community Area', 'FBI Code', 'X Coordinate', 'Y Coordinate',
#        'Year', 'Latitude', 'Longitude', 'Time', 'Month', 'Day', 'Hour',
#        'Updated On Time', 'Updated On Year', 'Updated On Month',
#        'Updated On Day', 'Season', 'Crime Severity'],
#       dtype='object')

# %%
crime_data['Arrest'].unique()
# Out:
# array([ True, False])

# %%
#Find the total no of crime
total_crime = len(crime_data)

#Find the total no of arrested 
total_arrest = crime_data['Arrest'].sum()

#Find the arrest rate convert to percentage
arrest_rate = (total_arrest/total_crime) * 100
print(f'Overall Arrest Rate: {arrest_rate:.2f}')
# Out:
# Overall Arrest Rate: 16.27

# %%
#arrest rate by crime type
arrest_rate_by_crime_type = crime_data.groupby('Primary Type')['Arrest'].mean() * 100
arrest_rate_by_crime_type
# Out:
# Primary Type
# ARSON                                  0.000000
# ASSAULT                                9.574468
# BATTERY                               18.666667
# BURGLARY                              18.421053
# CONCEALED CARRY LICENSE VIOLATION    100.000000
# CRIMINAL DAMAGE                        6.306306
# CRIMINAL SEXUAL ASSAULT               22.222222
# CRIMINAL TRESPASS                     42.105263
# DECEPTIVE PRACTICE                     4.761905
# HOMICIDE                              60.000000
# INTERFERENCE WITH PUBLIC OFFICER     100.000000
# KIDNAPPING                             0.000000
# MOTOR VEHICLE THEFT                    7.920792
# NARCOTICS                             84.615385
# OFFENSE INVOLVING CHILDREN            26.666667
# OTHER OFFENSE                         32.075472
# PROSTITUTION                           0.000000
# PUBLIC PEACE VIOLATION                 0.000000
# ROBBERY                               22.500000
# SEX OFFENSE                            9.523810
# STALKING                              25.000000
# THEFT                                 11.330049
# WEAPONS VIOLATION                     60.000000
# Name: Arrest, dtype: float64

# %%
#Arrest rate by district
arrest_rate_by_district = crime_data.groupby('District')['Arrest'].mean() * 100
arrest_rate_by_district
# Out:
# District
# 1     17.647059
# 2      7.936508
# 3     10.526316
# 4      6.666667
# 5     22.500000
# 6     20.370370
# 7      5.405405
# 8     11.594203
# 9     18.421053
# 10    17.647059
# 11    23.076923
# 12     6.779661
# 14    30.434783
# 15    24.137931
# 16    24.242424
# 17    17.021277
# 18    18.421053
# 19     8.695652
# 20     4.347826
# 22    26.923077
# 24     7.692308
# 25    36.842105
# Name: Arrest, dtype: float64

# %%
#arrest rate by ward
arrest_rate_by_ward = crime_data.groupby('Ward')['Arrest'].mean() * 100
arrest_rate_by_ward
# Out:
# Ward
# 1     23.076923
# 2     11.111111
# 3      4.000000
# 4      4.545455
# 5     18.750000
# 6     15.789474
# 7      5.882353
# 8     12.903226
# 9     18.181818
# 10     6.666667
# 11    15.384615
# 12     0.000000
# 13    33.333333
# 14    10.526316
# 15    22.222222
# 16    13.043478
# 17    17.500000
# 18     0.000000
# 19    37.500000
# 20    12.903226
# 21    28.571429
# 22     0.000000
# 23    16.666667
# 24    21.428571
# 25     9.090909
# 26    45.000000
# 27    15.384615
# 28    12.903226
# 29    30.434783
# 30    18.750000
# 31    27.272727
# 32    26.666667
# 33    11.764706
# 34    23.076923
# 35    29.411765
# 36    29.411765
# 37    27.586207
# 38    20.000000
# 39    25.000000
# 40     6.666667
# 41    33.333333
# 42    27.272727
# 43     0.000000
# 44     0.000000
# 45    11.111111
# 46     4.761905
# 47    14.285714
# 48     6.666667
# 49    15.000000
# 50     6.666667
# Name: Arrest, dtype: float64

# %%
#arrest rate by year
arrest_rate_by_year = crime_data.groupby('Year')['Arrest'].mean()*100
arrest_rate_by_year
# Out:
# Year
# 2010    100.000000
# 2018      0.000000
# 2019     25.000000
# 2020    100.000000
# 2021    100.000000
# 2022     52.941176
# 2023     15.068493
# Name: Arrest, dtype: float64

# %%
# Plot arrest rate by crime type
plt.figure(figsize=(14, 7))
arrest_rate_by_crime_type.sort_values(ascending=False).plot(kind='bar')
plt.title('Arrest Rate by Crime Type')
plt.xlabel('Primary Type')
plt.ylabel('Arrest Rate (%)')
plt.show()

# %%
# Plot arrest rate by district
plt.figure(figsize=(14, 7))
arrest_rate_by_district.sort_values(ascending=False).plot(kind='bar')
plt.title('Arrest Rate by District')
plt.xlabel('District')
plt.ylabel('Arrest Rate (%)')
plt.show()

# %%
# Plot arrest rate by ward
plt.figure(figsize=(14, 7))
arrest_rate_by_ward.sort_values(ascending=False).plot(kind='bar')
plt.title('Arrest Rate by Ward')
plt.xlabel('Ward')
plt.ylabel('Arrest Rate (%)')
plt.show()

# %%
# Plot arrest rate by year
plt.figure(figsize=(14, 7))
arrest_rate_by_year.sort_values(ascending=False).plot(kind='bar')
plt.title('Arrest Rate by Year')
plt.xlabel('Year')
plt.ylabel('Arrest Rate (%)')
plt.show()

# %% [markdown]
# ## Domestic vs. Non-Domestic Crimes:
#
# Compare the characteristics and frequencies of domestic-related incidents versus non-domestic incidents

# %%
# Calculate the number of domestic and non-domestic incidents
domestic_crimes = crime_data[crime_data['Domestic'] == True]
non_domestic_crimes = crime_data[crime_data['Domestic'] == False]

# Calculate the number of domestic and non-domestic incidents by primary type
domestic_crimes_by_type = domestic_crimes['Primary Type'].value_counts()
non_domestic_crimes_by_type = non_domestic_crimes['Primary Type'].value_counts()

# Plot the number of domestic incidents by primary type
plt.figure(figsize=(14, 7))
domestic_crimes_by_type.plot(kind='bar', color='blue', alpha=0.6, label='Domestic')
non_domestic_crimes_by_type.plot(kind='bar', color='orange', alpha=0.6, label='Non-Domestic')
plt.title('Domestic vs. Non-Domestic Incidents by Crime Type')
plt.xlabel('Primary Type')
plt.ylabel('Number of Incidents')
plt.legend()
plt.show()

# Calculate the arrest rates for domestic and non-domestic incidents
domestic_arrest_rate = domestic_crimes['Arrest'].mean() * 100
non_domestic_arrest_rate = non_domestic_crimes['Arrest'].mean() * 100

print(f'Domestic Arrest Rate: {domestic_arrest_rate:.2f}%')
print(f'Non-Domestic Arrest Rate: {non_domestic_arrest_rate:.2f}%')

# Calculate the number of domestic and non-domestic incidents by district
domestic_crimes_by_district = domestic_crimes['District'].value_counts()
non_domestic_crimes_by_district = non_domestic_crimes['District'].value_counts()

# Plot the number of domestic incidents by district
plt.figure(figsize=(14, 7))
domestic_crimes_by_district.plot(kind='bar', color='blue', alpha=0.6, label='Domestic')
non_domestic_crimes_by_district.plot(kind='bar', color='orange', alpha=0.6, label='Non-Domestic')
plt.title('Domestic vs. Non-Domestic Incidents by District')
plt.xlabel('District')
plt.ylabel('Number of Incidents')
plt.legend()
plt.show()
# Out:
# Domestic Arrest Rate: 21.11%
# Non-Domestic Arrest Rate: 15.04%

# %% [markdown]
# # Location-Specific Analysis

# %% [markdown]
# ### Location Description Analysis:
#
# Investigate the most common locations for crimes (e.g., streets, parking lots, apartments) and see how crime types vary by location.

# %%
crime_data.columns
# Out:
# Index(['ID', 'Case Number', 'Block', 'IUCR', 'Primary Type', 'Description',
#        'Location Description', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'Community Area', 'FBI Code', 'X Coordinate', 'Y Coordinate',
#        'Year', 'Latitude', 'Longitude', 'Time', 'Month', 'Day', 'Hour',
#        'Updated On Time', 'Updated On Year', 'Updated On Month',
#        'Updated On Day', 'Season', 'Crime Severity'],
#       dtype='object')

# %%
crime_data['Location Description'].unique()
# Out:
# array(['STREET', 'PARKING LOT', 'APARTMENT', 'SMALL RETAIL STORE',
#        'PARKING LOT / GARAGE (NON RESIDENTIAL)', 'RESIDENCE - GARAGE',
#        'RESIDENCE - PORCH / HALLWAY', 'CURRENCY EXCHANGE', 'RESIDENCE',
#        'AUTO / BOAT / RV DEALERSHIP',
#        'POLICE FACILITY / VEHICLE PARKING LOT', 'DEPARTMENT STORE',
#        'CHA PARKING LOT / GROUNDS', 'RESTAURANT', 'GROCERY FOOD STORE',
#        'APPLIANCE STORE', 'CAR WASH', 'HOSPITAL BUILDING / GROUNDS',
#        'COMMERCIAL / BUSINESS OFFICE', 'SIDEWALK',
#        'DRIVEWAY - RESIDENTIAL', 'OTHER (SPECIFY)', 'PARK PROPERTY',
#        'ALLEY', 'BANK', 'DRUG STORE', 'VEHICLE NON-COMMERCIAL',
#        'RESIDENCE - YARD (FRONT / BACK)', 'BAR OR TAVERN',
#        'LAKEFRONT / WATERFRONT / RIVERBANK', 'SCHOOL - PUBLIC BUILDING',
#        'AIRPORT TERMINAL LOWER LEVEL - SECURE AREA',
#        'NURSING / RETIREMENT HOME', 'HOTEL / MOTEL', 'CONVENIENCE STORE',
#        'GAS STATION', 'CTA BUS STOP',
#        'AIRPORT TERMINAL UPPER LEVEL - NON-SECURE AREA',
#        'GOVERNMENT BUILDING / PROPERTY', 'TAVERN / LIQUOR STORE',
#        'CTA PLATFORM', 'COLLEGE / UNIVERSITY - RESIDENCE HALL',
#        'AIRPORT TERMINAL LOWER LEVEL - NON-SECURE AREA',
#        'VEHICLE - COMMERCIAL', 'SCHOOL - PUBLIC GROUNDS', 'WAREHOUSE',
#        'CTA TRAIN', 'CTA BUS', 'ATM (AUTOMATIC TELLER MACHINE)',
#        'AIRPORT TERMINAL UPPER LEVEL - SECURE AREA', 'CONSTRUCTION SITE',
#        'AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA', 'ATHLETIC CLUB',
#        'CHURCH / SYNAGOGUE / PLACE OF WORSHIP', 'CTA STATION', 'CEMETARY',
#        'ABANDONED BUILDING', 'VACANT LOT / LAND',
#        'CHA HALLWAY / STAIRWELL / ELEVATOR', 'SCHOOL - PRIVATE GROUNDS',
#        'CHA APARTMENT', 'CTA TRACKS - RIGHT OF WAY'], dtype=object)

# %%
# Analyze the most common locations for crimes
location_counts = crime_data['Location Description'].value_counts().sort_values(ascending=True).head(20)

# Plot the most common locations for crimes
plt.figure(figsize=(15, 21))
location_counts.plot(kind='barh')
plt.title('Most Common Locations for Crimes (Top 20)')
plt.xlabel('Location Description')
plt.ylabel('Frequency')
plt.show()

# %%
# Crime types by location description
location_crime_type = crime_data.groupby(['Location Description', 'Primary Type']).size().unstack().fillna(0)

# Plot a heatmap of crime types by location description (Top 10 locations for readability)
top_locations = location_counts.index
plt.figure(figsize=(14, 10))
sns.heatmap(location_crime_type.loc[top_locations], cmap='YlGnBu', annot=True, fmt='.0f')
plt.title('Crime Types by Location Description (Top 10 Locations)')
plt.xlabel('Primary Type')
plt.ylabel('Location Description')
plt.show()

# %% [markdown]
# ## Comparison by Beat and Community Area:
#
# Analyze crime data by beat and community area to identify localized crime patterns and hotspots.

# %%
crime_data.columns
# Out:
# Index(['ID', 'Case Number', 'Block', 'IUCR', 'Primary Type', 'Description',
#        'Location Description', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'Community Area', 'FBI Code', 'X Coordinate', 'Y Coordinate',
#        'Year', 'Latitude', 'Longitude', 'Time', 'Month', 'Day', 'Hour',
#        'Updated On Time', 'Updated On Year', 'Updated On Month',
#        'Updated On Day', 'Season', 'Crime Severity'],
#       dtype='object')

# %%
crime_data['Beat'].nunique()
# Out:
# 255

# %%
# Analyze crime data by beat
crimes_by_beat = crime_data['Beat'].value_counts().sort_values(ascending=False).head(20)

# Plot crimes by beat
plt.figure(figsize=(21, 7))
crimes_by_beat.plot(kind='barh')
plt.title('Crimes by Beat')
plt.xlabel('No of Crimes')
plt.ylabel('Beat')
plt.show()

# Analyze crime data by community area
crimes_by_community_area = crime_data['Community Area'].value_counts().sort_values(ascending=False).head(50)

# Plot crimes by community area
plt.figure(figsize=(25, 7))
crimes_by_community_area.plot(kind='bar')
plt.title('Crimes by Community Area')
plt.xlabel('Community Area')
plt.ylabel('Number of Crimes')
plt.show()

# %% [markdown]
# ## Seasonal and Weather Impact
#
# Seasonal Trends: Examine whether certain types of crimes are more prevalent in specific seasons (e.g., summer vs. winter).

# %%
crime_data['Season'].unique()
# Out:
# array(['Spring', 'Summer', 'Fall', 'Winter'], dtype=object)

# %%
# Analyze the number of crimes by season
crimes_by_season = crime_data['Season'].value_counts()

# Plot the number of crimes by season
plt.figure(figsize=(10, 6))
crimes_by_season.plot(kind='bar', color=['blue', 'green', 'red', 'orange'])
plt.title('Number of Crimes by Season')
plt.xlabel('Season')
plt.ylabel('Number of Crimes')
plt.show()

# Analyze the number of crimes by primary type and season
crimes_by_type_and_season = crime_data.groupby(['Season', 'Primary Type']).size().unstack().fillna(0)

# Plot a heatmap of crimes by primary type and season
plt.figure(figsize=(14, 10))
sns.heatmap(crimes_by_type_and_season, cmap='YlGnBu', annot=True, fmt='.0f')
plt.title('Crimes by Primary Type and Season')
plt.xlabel('Primary Type')
plt.ylabel('Season')
plt.show()

# %% [markdown]
# ## Repeat Offenders and Recidivism
#    - Repeat Crime Locations: Identify locations that are repeatedly associated with criminal activity.

# %%
crime_data.head()
# Out:
#          ID Case Number                      Block  IUCR     Primary Type  \
# 0     25953    JE240540        020XX N LARAMIE AVE   110         HOMICIDE
# 1     26038    JE279849      062XX N MC CORMICK RD   110         HOMICIDE
# 2  13279676    JG507211           019XX W BYRON ST   620         BURGLARY
# 3  13274752    JG501049  086XX S COTTAGE GROVE AVE   454          BATTERY
# 4  13203321    JG415333           002XX N Wells st  1320  CRIMINAL DAMAGE
#
#                                          Description  \
# 0                                FIRST DEGREE MURDER
# 1                                FIRST DEGREE MURDER
# 2                                     UNLAWFUL ENTRY
# 3  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
# 4                                         TO VEHICLE
#
#                      Location Description  Arrest  Domestic  Beat  ...  \
# 0                                  STREET    True     False  2515  ...
# 1                             PARKING LOT    True     False  1711  ...
# 2                               APARTMENT   False     False  1922  ...
# 3                      SMALL RETAIL STORE    True     False   632  ...
# 4  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False   122  ...
#
#        Time  Month  Day Hour  Updated On Time  Updated On Year  \
# 0  15:06:00      5   24   15         15:39:49             2023
# 1  09:24:00      6   26    9         15:39:49             2023
# 2  07:30:00     11    9    7         15:39:49             2023
# 3  07:59:00     11   12    7         15:41:24             2023
# 4  17:00:00      9    6   17         15:40:18             2023
#
#    Updated On Month  Updated On Day  Season Crime Severity
# 0                11              18  Spring         Severe
# 1                11              18  Summer         Severe
# 2                11              18    Fall    Less Severe
# 3                12               9    Fall    Less Severe
# 4                11               4    Fall    Less Severe
#
# [5 rows x 29 columns]

# %%
crime_data['Location Description'].unique()
# Out:
# array(['STREET', 'PARKING LOT', 'APARTMENT', 'SMALL RETAIL STORE',
#        'PARKING LOT / GARAGE (NON RESIDENTIAL)', 'RESIDENCE - GARAGE',
#        'RESIDENCE - PORCH / HALLWAY', 'CURRENCY EXCHANGE', 'RESIDENCE',
#        'AUTO / BOAT / RV DEALERSHIP',
#        'POLICE FACILITY / VEHICLE PARKING LOT', 'DEPARTMENT STORE',
#        'CHA PARKING LOT / GROUNDS', 'RESTAURANT', 'GROCERY FOOD STORE',
#        'APPLIANCE STORE', 'CAR WASH', 'HOSPITAL BUILDING / GROUNDS',
#        'COMMERCIAL / BUSINESS OFFICE', 'SIDEWALK',
#        'DRIVEWAY - RESIDENTIAL', 'OTHER (SPECIFY)', 'PARK PROPERTY',
#        'ALLEY', 'BANK', 'DRUG STORE', 'VEHICLE NON-COMMERCIAL',
#        'RESIDENCE - YARD (FRONT / BACK)', 'BAR OR TAVERN',
#        'LAKEFRONT / WATERFRONT / RIVERBANK', 'SCHOOL - PUBLIC BUILDING',
#        'AIRPORT TERMINAL LOWER LEVEL - SECURE AREA',
#        'NURSING / RETIREMENT HOME', 'HOTEL / MOTEL', 'CONVENIENCE STORE',
#        'GAS STATION', 'CTA BUS STOP',
#        'AIRPORT TERMINAL UPPER LEVEL - NON-SECURE AREA',
#        'GOVERNMENT BUILDING / PROPERTY', 'TAVERN / LIQUOR STORE',
#        'CTA PLATFORM', 'COLLEGE / UNIVERSITY - RESIDENCE HALL',
#        'AIRPORT TERMINAL LOWER LEVEL - NON-SECURE AREA',
#        'VEHICLE - COMMERCIAL', 'SCHOOL - PUBLIC GROUNDS', 'WAREHOUSE',
#        'CTA TRAIN', 'CTA BUS', 'ATM (AUTOMATIC TELLER MACHINE)',
#        'AIRPORT TERMINAL UPPER LEVEL - SECURE AREA', 'CONSTRUCTION SITE',
#        'AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA', 'ATHLETIC CLUB',
#        'CHURCH / SYNAGOGUE / PLACE OF WORSHIP', 'CTA STATION', 'CEMETARY',
#        'ABANDONED BUILDING', 'VACANT LOT / LAND',
#        'CHA HALLWAY / STAIRWELL / ELEVATOR', 'SCHOOL - PRIVATE GROUNDS',
#        'CHA APARTMENT', 'CTA TRACKS - RIGHT OF WAY'], dtype=object)

# %%
location = crime_data[crime_data['Location Description'] == 'STREET']
location
# Out:
#            ID Case Number                 Block  IUCR         Primary Type  \
# 0       25953    JE240540   020XX N LARAMIE AVE   110             HOMICIDE
# 5    13210088    JG423627  023XX W JACKSON BLVD  1153   DECEPTIVE PRACTICE
# 12   13210035    JG422370       019XX W 71ST ST   820                THEFT
# 15   13278080    JG500620    038XX W MADISON ST   910  MOTOR VEHICLE THEFT
# 18   13276884    JG503649  043XX W AUGUSTA BLVD   910  MOTOR VEHICLE THEFT
# ..        ...         ...                   ...   ...                  ...
# 957  13203242    JG415334    050XX N KEELER AVE   920  MOTOR VEHICLE THEFT
# 959  13202510    JG414416       002XX E 29TH ST   610             BURGLARY
# 966  13203120    JG415081    044XX N SIMONDS DR  1320      CRIMINAL DAMAGE
# 971  13202913    JG414822  113XX S HOMEWOOD AVE  143A    WEAPONS VIOLATION
# 973  13202672    JG414584   071XX S LANGLEY AVE   910  MOTOR VEHICLE THEFT
#
#                              Description Location Description  Arrest  \
# 0                    FIRST DEGREE MURDER               STREET    True
# 5    FINANCIAL IDENTITY THEFT OVER $ 300               STREET   False
# 12                        $500 AND UNDER               STREET   False
# 15                            AUTOMOBILE               STREET   False
# 18                            AUTOMOBILE               STREET   False
# ..                                   ...                  ...     ...
# 957                 ATTEMPT - AUTOMOBILE               STREET    True
# 959                       FORCIBLE ENTRY               STREET   False
# 966                           TO VEHICLE               STREET   False
# 971        UNLAWFUL POSSESSION - HANDGUN               STREET    True
# 973                           AUTOMOBILE               STREET   False
#
#      Domestic  Beat  ...      Time  Month  Day Hour  Updated On Time  \
# 0       False  2515  ...  15:06:00      5   24   15         15:39:49
# 5       False  1225  ...  12:00:00      8   31   12         15:41:56
# 12      False   735  ...  07:00:00      8   17    7         15:41:56
# 15      False  1122  ...  00:00:00     11   11    0         15:40:25
# 18      False  1111  ...  17:30:00     11   10   17         15:40:25
# ..        ...   ...  ...       ...    ...  ...  ...              ...
# 957     False  1712  ...  17:25:00      9    7   17         15:42:23
# 959     False   133  ...  03:00:00      9    7    3         15:40:50
# 966     False  1914  ...  13:30:00      9    7   13         15:42:23
# 971     False  2212  ...  11:32:00      9    7   11         15:42:23
# 973     False   323  ...  00:01:00      9    7    0         15:42:23
#
#      Updated On Year  Updated On Month  Updated On Day  Season Crime Severity
# 0               2023                11              18  Spring         Severe
# 5               2023                 9              16  Summer    Less Severe
# 12              2023                 9              16  Summer    Less Severe
# 15              2023                11              18    Fall    Less Severe
# 18              2023                11              18    Fall    Less Severe
# ..               ...               ...             ...     ...            ...
# 957             2023                 9              15    Fall    Less Severe
# 959             2023                10               9    Fall    Less Severe
# 966             2023                 9              15    Fall    Less Severe
# 971             2023                 9              15    Fall    Less Severe
# 973             2023                 9              15    Fall    Less Severe
#
# [289 rows x 29 columns]

# %%
location['Primary Type'].nunique()
# Out:
# 18

# %%
repeat = location[location['Primary Type'] == 'CRIMINAL DAMAGE']
repeat
# Out:
#            ID Case Number                      Block  IUCR     Primary Type  \
# 89   13273800    JG499340        012XX S WESTERN AVE  1320  CRIMINAL DAMAGE
# 91   13273013    JG499374     072XX S DORCHESTER AVE  1320  CRIMINAL DAMAGE
# 96   13206294    JG418967      014XX N WASHTENAW AVE  1320  CRIMINAL DAMAGE
# 97   13201410    JG413245            006XX W ROOT ST  1340  CRIMINAL DAMAGE
# 109  13201900    JG413921            057XX W ERIE ST  1320  CRIMINAL DAMAGE
# 111  13202670    JG413315        068XX S NORMAL BLVD  1310  CRIMINAL DAMAGE
# 112  13202216    JG414059           018XX N LUNA AVE  1310  CRIMINAL DAMAGE
# 115  13202922    JG414619            014XX E 49TH ST  1320  CRIMINAL DAMAGE
# 127  13202257    JG414361       021XX S MICHIGAN AVE  1320  CRIMINAL DAMAGE
# 152  13201754    JG413725         082XX S VERNON AVE  1320  CRIMINAL DAMAGE
# 173  13202244    JG414262       035XX W ARMITAGE AVE  1320  CRIMINAL DAMAGE
# 194  13201501    JG413395         082XX S AVALON AVE  1320  CRIMINAL DAMAGE
# 206  13201967    JG414044       067XX S CAMPBELL AVE  1320  CRIMINAL DAMAGE
# 227  13202209    JG414282          080XX S PEORIA ST  1320  CRIMINAL DAMAGE
# 233  13202293    JG414323        040XX N KENMORE AVE  1320  CRIMINAL DAMAGE
# 256  13202933    JG414643      048XX S LAKE PARK AVE  1320  CRIMINAL DAMAGE
# 257  13202139    JG414210            028XX E 90TH ST  1320  CRIMINAL DAMAGE
# 272  13202937    JG414638      048XX S LAKE PARK AVE  1320  CRIMINAL DAMAGE
# 280  13202985    JG415105       034XX W ARMITAGE AVE  1320  CRIMINAL DAMAGE
# 368  13201794    JG413734          042XX W MONROE ST  1320  CRIMINAL DAMAGE
# 369  13203004    JG415117      048XX W KAMERLING AVE  1320  CRIMINAL DAMAGE
# 372  13202931    JG414680      048XX S LAKE PARK AVE  1320  CRIMINAL DAMAGE
# 386  13201751    JG413719      134XX S BALTIMORE AVE  1320  CRIMINAL DAMAGE
# 390  13201254    JG413005        111XX S LANGLEY AVE  1320  CRIMINAL DAMAGE
# 411  13202939    JG414564     048XX S DORCHESTER AVE  1320  CRIMINAL DAMAGE
# 439  13203505    JG414425            061XX S TROY ST  1320  CRIMINAL DAMAGE
# 544  13202174    JG414139       080XX S MUSKEGON AVE  1320  CRIMINAL DAMAGE
# 546  13202919    JG414633      048XX S LAKE PARK AVE  1320  CRIMINAL DAMAGE
# 566  13202821    JG414582            010XX E 41ST PL  1320  CRIMINAL DAMAGE
# 596  13202508    JG414545     049XX S BLACKSTONE AVE  1320  CRIMINAL DAMAGE
# 599  13201796    JG413762       004XX N ST LOUIS AVE  1320  CRIMINAL DAMAGE
# 602  13202926    JG414611            014XX E 49TH ST  1320  CRIMINAL DAMAGE
# 621  13201763    JG413588            003XX W 23RD ST  1320  CRIMINAL DAMAGE
# 622  13201775    JG413827      006XX W HUTCHINSON ST  1320  CRIMINAL DAMAGE
# 673  13202923    JG414804      044XX S LAKE PARK AVE  1320  CRIMINAL DAMAGE
# 681  13203656    JG415835   008XX E DREXEL SQUARE DR  1320  CRIMINAL DAMAGE
# 706  13201354    JG413206          047XX S LAMON AVE  1320  CRIMINAL DAMAGE
# 707  13201902    JG414070  079XX S SOUTH CHICAGO AVE  1320  CRIMINAL DAMAGE
# 763  13202223    JG414220         078XX S HALSTED ST  1345  CRIMINAL DAMAGE
# 766  13202413    JG414473      048XX S LAKE PARK AVE  1320  CRIMINAL DAMAGE
# 784  13202936    JG414579     048XX S DORCHESTER AVE  1320  CRIMINAL DAMAGE
# 789  13201275    JG413118           007XX N NOBLE ST  1320  CRIMINAL DAMAGE
# 808  13202689    JG414731      044XX S LAKE PARK AVE  1320  CRIMINAL DAMAGE
# 819  13205347    JG417375        028XX S PRAIRIE AVE  1320  CRIMINAL DAMAGE
# 824  13202504    JG414534            005XX E 33RD PL  1320  CRIMINAL DAMAGE
# 878  13272687    JG498877         023XX S SAWYER AVE  1320  CRIMINAL DAMAGE
# 897  13203378    JG415568            014XX W 63RD ST  1345  CRIMINAL DAMAGE
# 902  13203095    JG415194       047XX W BERENICE AVE  1310  CRIMINAL DAMAGE
# 910  13203765    JG415879         029XX N HARLEM AVE  1320  CRIMINAL DAMAGE
# 912  13203482    JG415655           013XX W 107TH ST  1320  CRIMINAL DAMAGE
# 916  13202686    JG414529            010XX E 41ST PL  1320  CRIMINAL DAMAGE
# 921  13202282    JG414347            018XX W 77TH ST  1320  CRIMINAL DAMAGE
# 935  13209091    JG422226       008XX N LECLAIRE AVE  1320  CRIMINAL DAMAGE
# 966  13203120    JG415081         044XX N SIMONDS DR  1320  CRIMINAL DAMAGE
#
#                      Description Location Description  Arrest  Domestic  Beat  \
# 89                    TO VEHICLE               STREET   False      True  1233
# 91                    TO VEHICLE               STREET   False     False   324
# 96                    TO VEHICLE               STREET   False     False  1423
# 97   TO STATE SUPPORTED PROPERTY               STREET   False     False   925
# 109                   TO VEHICLE               STREET   False     False  1511
# 111                  TO PROPERTY               STREET   False      True   722
# 112                  TO PROPERTY               STREET   False     False  2532
# 115                   TO VEHICLE               STREET   False     False   222
# 127                   TO VEHICLE               STREET   False     False   132
# 152                   TO VEHICLE               STREET   False     False   631
# 173                   TO VEHICLE               STREET   False     False  1422
# 194                   TO VEHICLE               STREET   False     False   411
# 206                   TO VEHICLE               STREET   False     False   832
# 227                   TO VEHICLE               STREET   False     False   621
# 233                   TO VEHICLE               STREET   False     False  1915
# 256                   TO VEHICLE               STREET   False     False   222
# 257                   TO VEHICLE               STREET   False     False   423
# 272                   TO VEHICLE               STREET   False     False   222
# 280                   TO VEHICLE               STREET   False     False  1422
# 368                   TO VEHICLE               STREET   False     False  1115
# 369                   TO VEHICLE               STREET   False      True  2533
# 372                   TO VEHICLE               STREET   False     False   222
# 386                   TO VEHICLE               STREET   False     False   433
# 390                   TO VEHICLE               STREET   False     False   531
# 411                   TO VEHICLE               STREET   False     False   222
# 439                   TO VEHICLE               STREET   False     False   823
# 544                   TO VEHICLE               STREET   False      True   422
# 546                   TO VEHICLE               STREET   False     False   222
# 566                   TO VEHICLE               STREET   False     False   214
# 596                   TO VEHICLE               STREET   False     False   222
# 599                   TO VEHICLE               STREET   False      True  1123
# 602                   TO VEHICLE               STREET   False     False   222
# 621                   TO VEHICLE               STREET   False     False   914
# 622                   TO VEHICLE               STREET   False     False  1915
# 673                   TO VEHICLE               STREET   False     False   222
# 681                   TO VEHICLE               STREET   False     False   233
# 706                   TO VEHICLE               STREET   False     False   814
# 707                   TO VEHICLE               STREET   False     False   411
# 763  TO CITY OF CHICAGO PROPERTY               STREET    True     False   621
# 766                   TO VEHICLE               STREET   False     False   222
# 784                   TO VEHICLE               STREET   False     False   222
# 789                   TO VEHICLE               STREET   False     False  1215
# 808                   TO VEHICLE               STREET   False     False   222
# 819                   TO VEHICLE               STREET   False     False   133
# 824                   TO VEHICLE               STREET   False     False   211
# 878                   TO VEHICLE               STREET   False     False  1024
# 897  TO CITY OF CHICAGO PROPERTY               STREET   False     False   713
# 902                  TO PROPERTY               STREET   False     False  1731
# 910                   TO VEHICLE               STREET   False     False  2511
# 912                   TO VEHICLE               STREET   False     False  2232
# 916                   TO VEHICLE               STREET   False     False   214
# 921                   TO VEHICLE               STREET   False     False   611
# 935                   TO VEHICLE               STREET   False     False  1531
# 966                   TO VEHICLE               STREET   False     False  1914
#
#      ...      Time  Month  Day Hour  Updated On Time  Updated On Year  \
# 89   ...  18:00:00     11   10   18         15:40:25             2023
# 91   ...  18:30:00     11   10   18         15:40:25             2023
# 96   ...  14:00:00      9    6   14         15:43:09             2023
# 97   ...  09:22:00      9    6    9         15:43:09             2023
# 109  ...  17:05:00      9    6   17         15:43:09             2023
# 111  ...  08:15:00      9    6    8         15:43:09             2023
# 112  ...  18:20:00      9    6   18         15:43:09             2023
# 115  ...  18:00:00      9    6   18         15:43:09             2023
# 127  ...  20:49:00      9    6   20         15:43:09             2023
# 152  ...  02:30:00      9    6    2         15:43:09             2023
# 173  ...  21:55:00      9    6   21         15:43:09             2023
# 194  ...  01:00:00      9    6    1         15:43:09             2023
# 206  ...  07:00:00      9    6    7         15:43:09             2023
# 227  ...  22:18:00      9    6   22         15:43:09             2023
# 233  ...  23:58:00      9    6   23         15:43:09             2023
# 256  ...  18:00:00      9    6   18         15:43:09             2023
# 257  ...  21:00:00      9    6   21         15:43:09             2023
# 272  ...  18:00:00      9    6   18         15:43:09             2023
# 280  ...  21:30:00      9    6   21         15:43:09             2023
# 368  ...  14:30:00      9    6   14         15:43:09             2023
# 369  ...  15:00:00      9    6   15         15:43:09             2023
# 372  ...  18:00:00      9    6   18         15:43:09             2023
# 386  ...  12:30:00      9    6   12         15:43:09             2023
# 390  ...  03:07:00      9    6    3         15:43:09             2023
# 411  ...  18:00:00      9    6   18         15:43:09             2023
# 439  ...  19:00:00      9    6   19         15:43:09             2023
# 544  ...  16:54:00      9    6   16         15:43:09             2023
# 546  ...  18:00:00      9    6   18         15:43:09             2023
# 566  ...  15:30:00      9    6   15         15:43:09             2023
# 596  ...  16:00:00      9    6   16         15:43:09             2023
# 599  ...  08:00:00      9    6    8         15:43:09             2023
# 602  ...  18:00:00      9    6   18         15:43:09             2023
# 621  ...  03:00:00      9    6    3         15:43:09             2023
# 622  ...  13:00:00      9    6   13         15:43:09             2023
# 673  ...  18:00:00      9    6   18         15:43:09             2023
# 681  ...  00:00:00      9    7    0         15:43:09             2023
# 706  ...  07:54:00      9    6    7         15:43:09             2023
# 707  ...  17:30:00      9    6   17         15:43:09             2023
# 763  ...  21:15:00      9    6   21         15:43:09             2023
# 766  ...  20:57:00      9    6   20         15:43:09             2023
# 784  ...  18:00:00      9    6   18         15:43:09             2023
# 789  ...  00:01:00      9    6    0         15:43:09             2023
# 808  ...  00:00:00      9    7    0         15:43:09             2023
# 819  ...  22:30:00      9    6   22         15:43:09             2023
# 824  ...  10:00:00      9    6   10         15:43:09             2023
# 878  ...  01:00:00     11   10    1         15:40:25             2023
# 897  ...  16:03:00      9    7   16         15:42:23             2023
# 902  ...  03:25:00      9    7    3         15:42:23             2023
# 910  ...  00:00:00      9    8    0         15:42:23             2023
# 912  ...  20:00:00      9    7   20         15:42:23             2023
# 916  ...  07:30:00      9    7    7         15:42:23             2023
# 921  ...  00:16:00      9    7    0         15:42:23             2023
# 935  ...  08:30:00      8   29    8         15:41:25             2023
# 966  ...  13:30:00      9    7   13         15:42:23             2023
#
#      Updated On Month  Updated On Day  Season Crime Severity
# 89                 11              18    Fall    Less Severe
# 91                 11              18    Fall    Less Severe
# 96                  9              14    Fall    Less Severe
# 97                  9              14    Fall    Less Severe
# 109                 9              14    Fall    Less Severe
# 111                 9              14    Fall    Less Severe
# 112                 9              14    Fall    Less Severe
# 115                 9              14    Fall    Less Severe
# 127                 9              14    Fall    Less Severe
# 152                 9              14    Fall    Less Severe
# 173                 9              14    Fall    Less Severe
# 194                 9              14    Fall    Less Severe
# 206                 9              14    Fall    Less Severe
# 227                 9              14    Fall    Less Severe
# 233                 9              14    Fall    Less Severe
# 256                 9              14    Fall    Less Severe
# 257                 9              14    Fall    Less Severe
# 272                 9              14    Fall    Less Severe
# 280                 9              14    Fall    Less Severe
# 368                 9              14    Fall    Less Severe
# 369                 9              14    Fall    Less Severe
# 372                 9              14    Fall    Less Severe
# 386                 9              14    Fall    Less Severe
# 390                 9              14    Fall    Less Severe
# 411                 9              14    Fall    Less Severe
# 439                 9              14    Fall    Less Severe
# 544                 9              14    Fall    Less Severe
# 546                 9              14    Fall    Less Severe
# 566                 9              14    Fall    Less Severe
# 596                 9              14    Fall    Less Severe
# 599                 9              14    Fall    Less Severe
# 602                 9              14    Fall    Less Severe
# 621                 9              14    Fall    Less Severe
# 622                 9              14    Fall    Less Severe
# 673                 9              14    Fall    Less Severe
# 681                 9              14    Fall    Less Severe
# 706                 9              14    Fall    Less Severe
# 707                 9              14    Fall    Less Severe
# 763                 9              14    Fall    Less Severe
# 766                 9              14    Fall    Less Severe
# 784                 9              14    Fall    Less Severe
# 789                 9              14    Fall    Less Severe
# 808                 9              14    Fall    Less Severe
# 819                 9              14    Fall    Less Severe
# 824                 9              14    Fall    Less Severe
# 878                11              18    Fall    Less Severe
# 897                 9              15    Fall    Less Severe
# 902                 9              15    Fall    Less Severe
# 910                 9              15    Fall    Less Severe
# 912                 9              15    Fall    Less Severe
# 916                 9              15    Fall    Less Severe
# 921                 9              15    Fall    Less Severe
# 935                 9              15  Summer    Less Severe
# 966                 9              15    Fall    Less Severe
#
# [54 rows x 29 columns]

# %%
# Identify repeat crime locations
repeat_locations = crime_data['Location Description'].value_counts()[crime_data['Location Description'].value_counts() > 1]
repeat_locations = repeat_locations.head(20)

# Display repeat crime locations
print("Locations with Repeat Criminal Activity:")
print(repeat_locations)
# Out:
# Locations with Repeat Criminal Activity:
# Location Description
# STREET                                    289
# APARTMENT                                 185
# RESIDENCE                                 106
# PARKING LOT / GARAGE (NON RESIDENTIAL)     44
# SMALL RETAIL STORE                         28
# SIDEWALK                                   27
# ALLEY                                      24
# OTHER (SPECIFY)                            17
# RESIDENCE - GARAGE                         16
# RESIDENCE - PORCH / HALLWAY                16
# DEPARTMENT STORE                           16
# SCHOOL - PUBLIC GROUNDS                    15
# RESIDENCE - YARD (FRONT / BACK)            15
# COMMERCIAL / BUSINESS OFFICE               15
# RESTAURANT                                 14
# VEHICLE NON-COMMERCIAL                     14
# SCHOOL - PUBLIC BUILDING                   12
# PARK PROPERTY                              10
# GAS STATION                                10
# GROCERY FOOD STORE                          8
# Name: count, dtype: int64

# %%
# Plotting the data
plt.figure(figsize=(10, 6))
repeat_locations.plot(kind='pie')
plt.title('Locations with Repeat Criminal Activity')
plt.xlabel('Location Description')
plt.ylabel('Number of Crimes')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Recidivism Rates: If data on repeat offenders is available, analyze recidivism rates and factors contributing to repeat offenses.

# %%
# Assuming 'Repeat Offender' column is available
if 'Repeat Offender' in crime_data.columns:
    # Calculate recidivism rates
    total_crimes = crime_data.shape[0]
    total_repeat_crimes = crime_data['Repeat Offender'].sum()
    recidivism_rate = (total_repeat_crimes / total_crimes) * 100

    # Display recidivism rate
    print(f"Recidivism Rate: {recidivism_rate:.2f}%")
else:
    print("Data on repeat offenders is not available in the dataset.")
# Out:
# Data on repeat offenders is not available in the dataset.

# %%
crime_data.columns
# Out:
# Index(['ID', 'Case Number', 'Block', 'IUCR', 'Primary Type', 'Description',
#        'Location Description', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'Community Area', 'FBI Code', 'X Coordinate', 'Y Coordinate',
#        'Year', 'Latitude', 'Longitude', 'Time', 'Month', 'Day', 'Hour',
#        'Updated On Time', 'Updated On Year', 'Updated On Month',
#        'Updated On Day', 'Season', 'Crime Severity'],
#       dtype='object')

# %%
crime_data['Arrest']
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# Name: Arrest, Length: 977, dtype: bool

# %%
total_arrests = crime_data[crime_data['Arrest']== True].shape[0]
total_arrests
# Out:
# 159

# %%
crime_data['Year']==crime_data['Year']+1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# Name: Year, Length: 977, dtype: bool

# %%
recidivism_criteria = crime_data[(crime_data['Arrest'] == True) & (crime_data['Year']==crime_data['Year']+1)]
recidivism_criteria
# Out:
# Empty DataFrame
# Columns: [ID, Case Number, Block, IUCR, Primary Type, Description, Location Description, Arrest, Domestic, Beat, District, Ward, Community Area, FBI Code, X Coordinate, Y Coordinate, Year, Latitude, Longitude, Time, Month, Day, Hour, Updated On Time, Updated On Year, Updated On Month, Updated On Day, Season, Crime Severity]
# Index: []
#
# [0 rows x 29 columns]

# %%
recidivism_count = recidivism_criteria.shape[0]
# Calculate recidivism rate
recidivism_rate = (recidivism_count / total_arrests) * 100

print(f"Recidivism Rate: {recidivism_rate:.2f}%")
# Out:
# Recidivism Rate: 0.00%

# %% [markdown]
# ## Predictive Modeling and Risk Assessment
#    - Predictive Analysis: Develop models to predict future crime incidents based on historical data, time, location, and other relevant factors.
#    - Risk Assessment: Assess the risk of different areas and times for specific types of crimes to help in resource allocation for law enforcement.

# %%
crime_data.columns
# Out:
# Index(['ID', 'Case Number', 'Block', 'IUCR', 'Primary Type', 'Description',
#        'Location Description', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'Community Area', 'FBI Code', 'X Coordinate', 'Y Coordinate',
#        'Year', 'Latitude', 'Longitude', 'Time', 'Month', 'Day', 'Hour',
#        'Updated On Time', 'Updated On Year', 'Updated On Month',
#        'Updated On Day', 'Season', 'Crime Severity'],
#       dtype='object')

# %%
crime_data
# Out:
#            ID Case Number                      Block  IUCR  \
# 0       25953    JE240540        020XX N LARAMIE AVE   110
# 1       26038    JE279849      062XX N MC CORMICK RD   110
# 2    13279676    JG507211           019XX W BYRON ST   620
# 3    13274752    JG501049  086XX S COTTAGE GROVE AVE   454
# 4    13203321    JG415333           002XX N Wells st  1320
# ..        ...         ...                        ...   ...
# 972  13203421    JG415540         013XX S WABASH AVE   820
# 973  13202672    JG414584        071XX S LANGLEY AVE   910
# 974  13204410    JG416803            007XX W 72ND ST  1130
# 975  13204809    JG415669        083XX S BRANDON AVE   486
# 976  13208800    JG411427   067XX S STONY ISLAND AVE  1310
#
#             Primary Type                                        Description  \
# 0               HOMICIDE                                FIRST DEGREE MURDER
# 1               HOMICIDE                                FIRST DEGREE MURDER
# 2               BURGLARY                                     UNLAWFUL ENTRY
# 3                BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
# 4        CRIMINAL DAMAGE                                         TO VEHICLE
# ..                   ...                                                ...
# 972                THEFT                                     $500 AND UNDER
# 973  MOTOR VEHICLE THEFT                                         AUTOMOBILE
# 974   DECEPTIVE PRACTICE                           FRAUD OR CONFIDENCE GAME
# 975              BATTERY                            DOMESTIC BATTERY SIMPLE
# 976      CRIMINAL DAMAGE                                        TO PROPERTY
#
#                        Location Description  Arrest  Domestic  Beat  ...  \
# 0                                    STREET    True     False  2515  ...
# 1                               PARKING LOT    True     False  1711  ...
# 2                                 APARTMENT   False     False  1922  ...
# 3                        SMALL RETAIL STORE    True     False   632  ...
# 4    PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False   122  ...
# ..                                      ...     ...       ...   ...  ...
# 972                                   ALLEY   False     False   131  ...
# 973                                  STREET   False     False   323  ...
# 974                               RESIDENCE   False     False   732  ...
# 975                               APARTMENT   False      True   424  ...
# 976                              RESTAURANT   False     False   332  ...
#
#          Time  Month  Day Hour  Updated On Time  Updated On Year  \
# 0    15:06:00      5   24   15         15:39:49             2023
# 1    09:24:00      6   26    9         15:39:49             2023
# 2    07:30:00     11    9    7         15:39:49             2023
# 3    07:59:00     11   12    7         15:41:24             2023
# 4    17:00:00      9    6   17         15:40:18             2023
# ..        ...    ...  ...  ...              ...              ...
# 972  20:24:00      9    7   20         15:42:23             2023
# 973  00:01:00      9    7    0         15:42:23             2023
# 974  13:34:00      9    7   13         15:42:23             2023
# 975  20:30:00      9    7   20         15:42:23             2023
# 976  02:44:00      9    5    2         15:41:25             2023
#
#      Updated On Month  Updated On Day  Season Crime Severity
# 0                  11              18  Spring         Severe
# 1                  11              18  Summer         Severe
# 2                  11              18    Fall    Less Severe
# 3                  12               9    Fall    Less Severe
# 4                  11               4    Fall    Less Severe
# ..                ...             ...     ...            ...
# 972                 9              15    Fall    Less Severe
# 973                 9              15    Fall    Less Severe
# 974                 9              15    Fall    Less Severe
# 975                 9              15    Fall    Less Severe
# 976                 9              15    Fall    Less Severe
#
# [977 rows x 29 columns]

# %%
crime = crime_data.copy()

# %%
crime.columns
# Out:
# Index(['ID', 'Case Number', 'Block', 'IUCR', 'Primary Type', 'Description',
#        'Location Description', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'Community Area', 'FBI Code', 'X Coordinate', 'Y Coordinate',
#        'Year', 'Latitude', 'Longitude', 'Time', 'Month', 'Day', 'Hour',
#        'Updated On Time', 'Updated On Year', 'Updated On Month',
#        'Updated On Day', 'Season', 'Crime Severity'],
#       dtype='object')

# %%
crime = crime.drop(['ID','Case Number','Block','IUCR','Description','FBI Code','Time','X Coordinate','Y Coordinate',
                    'Updated On Time', 'Updated On Year', 'Updated On Month','Updated On Day','Beat',],axis=1)
crime.head()
# Out:
#       Primary Type                    Location Description  Arrest  Domestic  \
# 0         HOMICIDE                                  STREET    True     False
# 1         HOMICIDE                             PARKING LOT    True     False
# 2         BURGLARY                               APARTMENT   False     False
# 3          BATTERY                      SMALL RETAIL STORE    True     False
# 4  CRIMINAL DAMAGE  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False
#
#    District  Ward  Community Area  Year   Latitude  Longitude  Month  Day  \
# 0        25    36              19  2021  41.917838 -87.755969      5   24
# 1        17    50              13  2021  41.995219 -87.713355      6   26
# 2        19    47               5  2023  41.952345 -87.677975     11    9
# 3         6     6              44  2023  41.737751 -87.604856     11   12
# 4         1    42              32  2023  41.886018 -87.633938      9    6
#
#    Hour  Season Crime Severity
# 0    15  Spring         Severe
# 1     9  Summer         Severe
# 2     7    Fall    Less Severe
# 3     7    Fall    Less Severe
# 4    17    Fall    Less Severe

# %%
crime.columns
# Out:
# Index(['Primary Type', 'Location Description', 'Arrest', 'Domestic',
#        'District', 'Ward', 'Community Area', 'Year', 'Latitude', 'Longitude',
#        'Month', 'Day', 'Hour', 'Season', 'Crime Severity'],
#       dtype='object')

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Primary Type          977 non-null    object
#  1   Location Description  977 non-null    object
#  2   Arrest                977 non-null    bool
#  3   Domestic              977 non-null    bool
#  4   District              977 non-null    int64
#  5   Ward                  977 non-null    int64
#  6   Community Area        977 non-null    int64
#  7   Year                  977 non-null    int64
#  8   Latitude              977 non-null    float64
#  9   Longitude             977 non-null    float64
#  10  Month                 977 non-null    int64
#  11  Day                   977 non-null    int64
#  12  Hour                  977 non-null    int64
#  13  Season                977 non-null    object
#  14  Crime Severity        977 non-null    object
# dtypes: bool(2), float64(2), int64(7), object(4)
# memory usage: 101.3+ KB

# %%
new_crime = crime.copy()

# %%
new_crime['Primary Type'].unique()
# Out:
# array(['HOMICIDE', 'BURGLARY', 'BATTERY', 'CRIMINAL DAMAGE',
#        'DECEPTIVE PRACTICE', 'CRIMINAL SEXUAL ASSAULT', 'THEFT',
#        'OFFENSE INVOLVING CHILDREN', 'MOTOR VEHICLE THEFT', 'ROBBERY',
#        'ASSAULT', 'SEX OFFENSE', 'OTHER OFFENSE', 'WEAPONS VIOLATION',
#        'STALKING', 'CRIMINAL TRESPASS', 'PROSTITUTION', 'ARSON',
#        'NARCOTICS', 'KIDNAPPING', 'CONCEALED CARRY LICENSE VIOLATION',
#        'INTERFERENCE WITH PUBLIC OFFICER', 'PUBLIC PEACE VIOLATION'],
#       dtype=object)

# %%
new_crime['Primary Type'].nunique()
# Out:
# 23

# %%
typings = new_crime['Primary Type'].unique()
primary_mapping = {typing: idx + 1 for idx, typing in enumerate(typings)}
primary_mapping
# Out:
# {'HOMICIDE': 1,
#  'BURGLARY': 2,
#  'BATTERY': 3,
#  'CRIMINAL DAMAGE': 4,
#  'DECEPTIVE PRACTICE': 5,
#  'CRIMINAL SEXUAL ASSAULT': 6,
#  'THEFT': 7,
#  'OFFENSE INVOLVING CHILDREN': 8,
#  'MOTOR VEHICLE THEFT': 9,
#  'ROBBERY': 10,
#  'ASSAULT': 11,
#  'SEX OFFENSE': 12,
#  'OTHER OFFENSE': 13,
#  'WEAPONS VIOLATION': 14,
#  'STALKING': 15,
#  'CRIMINAL TRESPASS': 16,
#  'PROSTITUTION': 17,
#  'ARSON': 18,
#  'NARCOTICS': 19,
#  'KIDNAPPING': 20,
#  'CONCEALED CARRY LICENSE VIOLATION': 21,
#  'INTERFERENCE WITH PUBLIC OFFICER': 22,
#  'PUBLIC PEACE VIOLATION': 23}

# %%
new_crime['Primary Type'] = new_crime['Primary Type'].map(primary_mapping)
new_crime.head()
# Out:
#    Primary Type                    Location Description  Arrest  Domestic  \
# 0             1                                  STREET    True     False
# 1             1                             PARKING LOT    True     False
# 2             2                               APARTMENT   False     False
# 3             3                      SMALL RETAIL STORE    True     False
# 4             4  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False
#
#    District  Ward  Community Area  Year   Latitude  Longitude  Month  Day  \
# 0        25    36              19  2021  41.917838 -87.755969      5   24
# 1        17    50              13  2021  41.995219 -87.713355      6   26
# 2        19    47               5  2023  41.952345 -87.677975     11    9
# 3         6     6              44  2023  41.737751 -87.604856     11   12
# 4         1    42              32  2023  41.886018 -87.633938      9    6
#
#    Hour  Season Crime Severity
# 0    15  Spring         Severe
# 1     9  Summer         Severe
# 2     7    Fall    Less Severe
# 3     7    Fall    Less Severe
# 4    17    Fall    Less Severe

# %%
locations = new_crime['Location Description'].unique()
location_mapping = {location: idx + 1 for idx, location in enumerate(locations)}
location_mapping
# Out:
# {'STREET': 1,
#  'PARKING LOT': 2,
#  'APARTMENT': 3,
#  'SMALL RETAIL STORE': 4,
#  'PARKING LOT / GARAGE (NON RESIDENTIAL)': 5,
#  'RESIDENCE - GARAGE': 6,
#  'RESIDENCE - PORCH / HALLWAY': 7,
#  'CURRENCY EXCHANGE': 8,
#  'RESIDENCE': 9,
#  'AUTO / BOAT / RV DEALERSHIP': 10,
#  'POLICE FACILITY / VEHICLE PARKING LOT': 11,
#  'DEPARTMENT STORE': 12,
#  'CHA PARKING LOT / GROUNDS': 13,
#  'RESTAURANT': 14,
#  'GROCERY FOOD STORE': 15,
#  'APPLIANCE STORE': 16,
#  'CAR WASH': 17,
#  'HOSPITAL BUILDING / GROUNDS': 18,
#  'COMMERCIAL / BUSINESS OFFICE': 19,
#  'SIDEWALK': 20,
#  'DRIVEWAY - RESIDENTIAL': 21,
#  'OTHER (SPECIFY)': 22,
#  'PARK PROPERTY': 23,
#  'ALLEY': 24,
#  'BANK': 25,
#  'DRUG STORE': 26,
#  'VEHICLE NON-COMMERCIAL': 27,
#  'RESIDENCE - YARD (FRONT / BACK)': 28,
#  'BAR OR TAVERN': 29,
#  'LAKEFRONT / WATERFRONT / RIVERBANK': 30,
#  'SCHOOL - PUBLIC BUILDING': 31,
#  'AIRPORT TERMINAL LOWER LEVEL - SECURE AREA': 32,
#  'NURSING / RETIREMENT HOME': 33,
#  'HOTEL / MOTEL': 34,
#  'CONVENIENCE STORE': 35,
#  'GAS STATION': 36,
#  'CTA BUS STOP': 37,
#  'AIRPORT TERMINAL UPPER LEVEL - NON-SECURE AREA': 38,
#  'GOVERNMENT BUILDING / PROPERTY': 39,
#  'TAVERN / LIQUOR STORE': 40,
#  'CTA PLATFORM': 41,
#  'COLLEGE / UNIVERSITY - RESIDENCE HALL': 42,
#  'AIRPORT TERMINAL LOWER LEVEL - NON-SECURE AREA': 43,
#  'VEHICLE - COMMERCIAL': 44,
#  'SCHOOL - PUBLIC GROUNDS': 45,
#  'WAREHOUSE': 46,
#  'CTA TRAIN': 47,
#  'CTA BUS': 48,
#  'ATM (AUTOMATIC TELLER MACHINE)': 49,
#  'AIRPORT TERMINAL UPPER LEVEL - SECURE AREA': 50,
#  'CONSTRUCTION SITE': 51,
#  'AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA': 52,
#  'ATHLETIC CLUB': 53,
#  'CHURCH / SYNAGOGUE / PLACE OF WORSHIP': 54,
#  'CTA STATION': 55,
#  'CEMETARY': 56,
#  'ABANDONED BUILDING': 57,
#  'VACANT LOT / LAND': 58,
#  'CHA HALLWAY / STAIRWELL / ELEVATOR': 59,
#  'SCHOOL - PRIVATE GROUNDS': 60,
#  'CHA APARTMENT': 61,
#  'CTA TRACKS - RIGHT OF WAY': 62}

# %%
new_crime['Location Description'] = new_crime['Location Description'].map(location_mapping)
new_crime.head()
# Out:
#    Primary Type  Location Description  Arrest  Domestic  District  Ward  \
# 0             1                     1    True     False        25    36
# 1             1                     2    True     False        17    50
# 2             2                     3   False     False        19    47
# 3             3                     4    True     False         6     6
# 4             4                     5   False     False         1    42
#
#    Community Area  Year   Latitude  Longitude  Month  Day  Hour  Season  \
# 0              19  2021  41.917838 -87.755969      5   24    15  Spring
# 1              13  2021  41.995219 -87.713355      6   26     9  Summer
# 2               5  2023  41.952345 -87.677975     11    9     7    Fall
# 3              44  2023  41.737751 -87.604856     11   12     7    Fall
# 4              32  2023  41.886018 -87.633938      9    6    17    Fall
#
#   Crime Severity
# 0         Severe
# 1         Severe
# 2    Less Severe
# 3    Less Severe
# 4    Less Severe

# %%
arrersts = new_crime['Arrest'].unique()
arrerst_mapping = {arrerst: idx + 1 for idx, arrerst in enumerate(arrersts)}
arrerst_mapping
# Out:
# {True: 1, False: 2}

# %%
new_crime['Arrest'] = new_crime['Arrest'].map(arrerst_mapping)
new_crime.head()
# Out:
#    Primary Type  Location Description  Arrest  Domestic  District  Ward  \
# 0             1                     1       1     False        25    36
# 1             1                     2       1     False        17    50
# 2             2                     3       2     False        19    47
# 3             3                     4       1     False         6     6
# 4             4                     5       2     False         1    42
#
#    Community Area  Year   Latitude  Longitude  Month  Day  Hour  Season  \
# 0              19  2021  41.917838 -87.755969      5   24    15  Spring
# 1              13  2021  41.995219 -87.713355      6   26     9  Summer
# 2               5  2023  41.952345 -87.677975     11    9     7    Fall
# 3              44  2023  41.737751 -87.604856     11   12     7    Fall
# 4              32  2023  41.886018 -87.633938      9    6    17    Fall
#
#   Crime Severity
# 0         Severe
# 1         Severe
# 2    Less Severe
# 3    Less Severe
# 4    Less Severe

# %%
Seasons = new_crime['Season'].unique()
Season_mapping = {Season: idx + 1 for idx, Season in enumerate(Seasons)}
Season_mapping
# Out:
# {'Spring': 1, 'Summer': 2, 'Fall': 3, 'Winter': 4}

# %%
new_crime['Season'] = new_crime['Season'].map(Season_mapping)
new_crime.head()
# Out:
#    Primary Type  Location Description  Arrest  Domestic  District  Ward  \
# 0             1                     1       1     False        25    36
# 1             1                     2       1     False        17    50
# 2             2                     3       2     False        19    47
# 3             3                     4       1     False         6     6
# 4             4                     5       2     False         1    42
#
#    Community Area  Year   Latitude  Longitude  Month  Day  Hour  Season  \
# 0              19  2021  41.917838 -87.755969      5   24    15       1
# 1              13  2021  41.995219 -87.713355      6   26     9       2
# 2               5  2023  41.952345 -87.677975     11    9     7       3
# 3              44  2023  41.737751 -87.604856     11   12     7       3
# 4              32  2023  41.886018 -87.633938      9    6    17       3
#
#   Crime Severity
# 0         Severe
# 1         Severe
# 2    Less Severe
# 3    Less Severe
# 4    Less Severe

# %%
Domestics = new_crime['Domestic'].unique()
Domestic_mapping = {Domestic: idx + 1 for idx, Domestic in enumerate(Domestics)}
Domestic_mapping
# Out:
# {False: 1, True: 2}

# %%
new_crime['Domestic'] = new_crime['Domestic'].map(Domestic_mapping)
new_crime.head()
# Out:
#    Primary Type  Location Description  Arrest  Domestic  District  Ward  \
# 0             1                     1       1         1        25    36
# 1             1                     2       1         1        17    50
# 2             2                     3       2         1        19    47
# 3             3                     4       1         1         6     6
# 4             4                     5       2         1         1    42
#
#    Community Area  Year   Latitude  Longitude  Month  Day  Hour  Season  \
# 0              19  2021  41.917838 -87.755969      5   24    15       1
# 1              13  2021  41.995219 -87.713355      6   26     9       2
# 2               5  2023  41.952345 -87.677975     11    9     7       3
# 3              44  2023  41.737751 -87.604856     11   12     7       3
# 4              32  2023  41.886018 -87.633938      9    6    17       3
#
#   Crime Severity
# 0         Severe
# 1         Severe
# 2    Less Severe
# 3    Less Severe
# 4    Less Severe

# %%
Crimes = new_crime['Crime Severity'].unique()
Crimes_mapping = {Crime: idx + 1 for idx, Crime in enumerate(Crimes)}
Crimes_mapping
# Out:
# {'Severe': 1, 'Less Severe': 2}

# %%
new_crime['Crime Severity'] = new_crime['Crime Severity'].map(Crimes_mapping)
new_crime.head()
# Out:
#    Primary Type  Location Description  Arrest  Domestic  District  Ward  \
# 0             1                     1       1         1        25    36
# 1             1                     2       1         1        17    50
# 2             2                     3       2         1        19    47
# 3             3                     4       1         1         6     6
# 4             4                     5       2         1         1    42
#
#    Community Area  Year   Latitude  Longitude  Month  Day  Hour  Season  \
# 0              19  2021  41.917838 -87.755969      5   24    15       1
# 1              13  2021  41.995219 -87.713355      6   26     9       2
# 2               5  2023  41.952345 -87.677975     11    9     7       3
# 3              44  2023  41.737751 -87.604856     11   12     7       3
# 4              32  2023  41.886018 -87.633938      9    6    17       3
#
#    Crime Severity
# 0               1
# 1               1
# 2               2
# 3               2
# 4               2

# %%
new_crime['Longitude']
# Out:
# 0     -87.755969
# 1     -87.713355
# 2     -87.677975
# 3     -87.604856
# 4     -87.633938
#          ...
# 972   -87.625786
# 973   -87.607989
# 974   -87.643595
# 975   -87.546672
# 976   -87.586296
# Name: Longitude, Length: 977, dtype: float64

# %%
# Offset value
offset = 180

# Add offset to Longitude and create a new column
new_crime['Longitude'] = new_crime['Longitude'] + offset

# %%
new_crime['Longitude']
# Out:
# 0      92.244031
# 1      92.286645
# 2      92.322025
# 3      92.395144
# 4      92.366062
#          ...
# 972    92.374214
# 973    92.392011
# 974    92.356405
# 975    92.453328
# 976    92.413704
# Name: Longitude, Length: 977, dtype: float64

# %%
new_crime['Latitude'].min(),new_crime['Latitude'].max()
# Out:
# (41.648588776, 42.020295765)

# %%
new_crime['Longitude'].min(),new_crime['Longitude'].max()
# Out:
# (92.094772779, 92.469549033)

# %%
new_crime['Domestic'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
new_crime.columns
# Out:
# Index(['Primary Type', 'Location Description', 'Arrest', 'Domestic',
#        'District', 'Ward', 'Community Area', 'Year', 'Latitude', 'Longitude',
#        'Month', 'Day', 'Hour', 'Season', 'Crime Severity'],
#       dtype='object')

# %%
# find outliers - box plot & skewed data - hist plot and violin plot
def plot(df, column):
    plt.figure(figsize=(20,5))
    plt.subplot(1,3,1)
    sns.boxplot(data=df, x=column)
    plt.title(f'Box Plot for {column}')

    plt.subplot(1,3,2)
    sns.histplot(data=df, x=column, kde=True, bins=50)
    plt.title(f'Distribution Plot for {column}')

    plt.subplot(1,3,3)
    sns.violinplot(data=df, x=column)
    plt.title(f'Violin Plot for {column}')
    plt.show()

# %%
for i in ['Primary Type', 'Location Description', 'Domestic',
       'District', 'Ward', 'Community Area', 'Year', 'Latitude', 'Longitude',
       'Month', 'Day', 'Hour', 'Season', 'Crime Severity']:
    plot(new_crime, i)

# %%
columns = ['Primary Type', 'Location Description','District', 'Ward', 'Community Area', 'Latitude', 'Longitude', 'Hour']

for column in columns:
    mask = new_crime[column] < 0
    print(f'{column}: {mask.sum()}')
    new_crime.loc[mask, column] = np.nan
# Out:
# Primary Type: 0
# Location Description: 0
# District: 0
# Ward: 0
# Community Area: 0
# Latitude: 0
# Longitude: 0
# Hour: 0

# %%
columns = ['Primary Type', 'Location Description','District', 'Ward', 'Community Area', 'Latitude', 'Longitude', 'Hour']

for column in columns:
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = new_crime[column].quantile(0.25)
    Q3 = new_crime[column].quantile(0.75)
    IQR = Q3 - Q1

    # Calculate the lower and upper bound
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Identify outliers
    outliers_mask = (new_crime[column] < lower_bound) | (new_crime[column] > upper_bound)
    print(f'Column: {column}, Outliers: {outliers_mask.sum()}')

    # Replace outliers with NaN
    new_crime.loc[outliers_mask, column] = np.nan
# Out:
# Column: Primary Type, Outliers: 6
# Column: Location Description, Outliers: 56
# Column: District, Outliers: 0
# Column: Ward, Outliers: 0
# Column: Community Area, Outliers: 0
# Column: Latitude, Outliers: 0
# Column: Longitude, Outliers: 3
# Column: Hour, Outliers: 0

# %%
for i in ['Primary Type', 'Location Description', 'Domestic',
       'District', 'Ward', 'Community Area', 'Year', 'Latitude', 'Longitude',
       'Month', 'Day', 'Hour', 'Season', 'Crime Severity']:
    plot(new_crime, i)

# %%
new_crime.isnull().sum()
# Out:
# Primary Type             6
# Location Description    56
# Arrest                   0
# Domestic                 0
# District                 0
# Ward                     0
# Community Area           0
# Year                     0
# Latitude                 0
# Longitude                3
# Month                    0
# Day                      0
# Hour                     0
# Season                   0
# Crime Severity           0
# dtype: int64

# %%
new_crime.dropna(inplace=True)
new_crime.reset_index(drop=True,inplace=True)
len(new_crime)
# Out:
# 915

# %%
new_crime.head()
# Out:
#    Primary Type  Location Description  Arrest  Domestic  District  Ward  \
# 0           1.0                   1.0       1         1      25.0  36.0
# 1           1.0                   2.0       1         1      17.0  50.0
# 2           2.0                   3.0       2         1      19.0  47.0
# 3           3.0                   4.0       1         1       6.0   6.0
# 4           4.0                   5.0       2         1       1.0  42.0
#
#    Community Area  Year   Latitude  Longitude  Month  Day  Hour  Season  \
# 0            19.0  2021  41.917838  92.244031      5   24  15.0       1
# 1            13.0  2021  41.995219  92.286645      6   26   9.0       2
# 2             5.0  2023  41.952345  92.322025     11    9   7.0       3
# 3            44.0  2023  41.737751  92.395144     11   12   7.0       3
# 4            32.0  2023  41.886018  92.366062      9    6  17.0       3
#
#    Crime Severity
# 0               1
# 1               1
# 2               2
# 3               2
# 4               2

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# %%
X = new_crime.drop('Arrest',axis = 1)
y = new_crime['Arrest']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,random_state = 72)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (732, 14) (183, 14) (732,) (183,)

# %%
scaler = StandardScaler()
# Scale the training data and retain feature names
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)

# Scale the test data and retain feature names
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %%
# Fit the logistic regression model
Logistic_model = LogisticRegression(max_iter=1000)
Logistic_model.fit(X_train_scaled, y_train)

# Make predictions on the new data
new_crime['pred'] = Logistic_model.predict(X)
# Make predictions on the test data
y_pred = Logistic_model.predict(X_test_scaled)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro', zero_division=1)
recall = recall_score(y_test, y_pred, average='macro', zero_division=1)
f1 = f1_score(y_test, y_pred, average='macro', zero_division=1)
report = classification_report(y_test, y_pred, zero_division=1)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy: 0.8415300546448088
# Precision: 0.5155367231638418
# Recall: 0.5041772151898735
# F1 Score: 0.4889744824265768
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.17      0.04      0.06        25
#            2       0.86      0.97      0.91       158
#
#     accuracy                           0.84       183
#    macro avg       0.52      0.50      0.49       183
# weighted avg       0.77      0.84      0.80       183

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5)  # You can choose the number of neighbors
knn.fit(X_train, y_train)
new_crime['knn_pred'] = knn.predict(X)

print("\nK-Nearest Neighbors Performance:")
print(f"Accuracy: {accuracy_score(y, new_crime['knn_pred'])}")
print(f"Precision: {precision_score(y, new_crime['knn_pred'], average='macro')}")
print(f"Recall: {recall_score(y, new_crime['knn_pred'], average='macro')}")
print(f"F1 Score: {f1_score(y, new_crime['knn_pred'], average='macro')}")
print(f"Classification Report:\n{classification_report(y, new_crime['knn_pred'])}")
# Out:
# K-Nearest Neighbors Performance:
# Accuracy: 0.8568306010928962
# Precision: 0.7768526528258362
# Recall: 0.6009471323181523
# F1 Score: 0.6274024637784775
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.69      0.22      0.34       149
#            2       0.87      0.98      0.92       766
#
#     accuracy                           0.86       915
#    macro avg       0.78      0.60      0.63       915
# weighted avg       0.84      0.86      0.82       915

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_classifier =  RandomForestClassifier(n_estimators=200,random_state=42)

# Fit the classifier to the training data
rf_classifier.fit(X_train, y_train)

# Predict on the test set
y_pred_rf = rf_classifier.predict(X_test)

# Calculate classification metrics
accuracy = accuracy_score(y_test, y_pred_rf)
precision = precision_score(y_test, y_pred_rf, average='macro')
recall = recall_score(y_test, y_pred_rf, average='macro')
f1 = f1_score(y_test, y_pred_rf, average='macro')

print('Classification Metrics:')
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
print(f"Classification Report:\n{classification_report(y_test, y_pred_rf)}")
# Out:
# Classification Metrics:
# Accuracy: 0.8743169398907104
# Precision: 0.7333458083832336
# Recall: 0.6578481012658228
# F1 Score: 0.6841275797373358
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.56      0.36      0.44        25
#            2       0.90      0.96      0.93       158
#
#     accuracy                           0.87       183
#    macro avg       0.73      0.66      0.68       183
# weighted avg       0.86      0.87      0.86       183

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_class =  DecisionTreeClassifier()
dt_class.fit(X_train,y_train)

# Decision Tree Classifier
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
new_crime['tree_pred'] = tree.predict(X)

print("\nDecision Tree Classifier Performance:")
print(f"Accuracy: {accuracy_score(y, new_crime['tree_pred'])}")
print(f"Precision: {precision_score(y, new_crime['tree_pred'], average='macro', zero_division=0)}")
print(f"Recall: {recall_score(y, new_crime['tree_pred'], average='macro', zero_division=0)}")
print(f"F1 Score: {f1_score(y, new_crime['tree_pred'], average='macro', zero_division=0)}")
print(f"Classification Report:\n{classification_report(y, new_crime['tree_pred'])}")
# Out:
# Decision Tree Classifier Performance:
# Accuracy: 0.9573770491803278
# Precision: 0.9174019147737938
# Recall: 0.9285927068183013
# F1 Score: 0.9228734268318777
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.86      0.89      0.87       149
#            2       0.98      0.97      0.97       766
#
#     accuracy                           0.96       915
#    macro avg       0.92      0.93      0.92       915
# weighted avg       0.96      0.96      0.96       915

# %% [markdown]
# ## Predictive Analysis:
# Develop models to predict future crime incidents based on historical data, time, location, and other relevant factors.

# %%
offset = 180

# Add offset to Longitude and create a new column
X_test['Longitude'] = X_test['Longitude'] - offset

# %%
X_test['Longitude']
# Out:
# 362   -87.647150
# 423   -87.636752
# 502   -87.718827
# 648   -87.644305
# 722   -87.626498
#          ...
# 329   -87.639320
# 594   -87.637524
# 615   -87.682652
# 698   -87.693119
# 841   -87.794548
# Name: Longitude, Length: 183, dtype: float64

# %%
# Make future predictions (for simplicity, we'll use the test set as a proxy for future data)
y_future_pred = tree.predict(X_test_scaled)
X_test['pred'] = y_future_pred

# Aggregate predictions to identify high-risk areas and times
risk_assessment = X_test.groupby(['Latitude','Longitude', 'Hour', 'Day', 'Month']).agg({'pred': 'mean'}).reset_index()

# Identify high-risk areas and times
high_risk_areas = risk_assessment.sort_values(by='pred', ascending=False).head(25)  # Top 25 high-risk areas
print(high_risk_areas)
# Out:
#       Latitude  Longitude  Hour  Day  Month  pred
# 0    41.654834 -87.607558  13.0    1      9   1.0
# 115  41.887522 -87.624553  20.0    6      9   1.0
# 117  41.890674 -87.685786  15.0    5      9   1.0
# 118  41.891119 -87.686707  20.0    6      9   1.0
# 119  41.892570 -87.622058  13.0    6      9   1.0
# 120  41.895014 -87.675741  18.0    6      9   1.0
# 121  41.895409 -87.753167   8.0   29      8   1.0
# 122  41.895450 -87.653585   8.0    6      9   1.0
# 123  41.895515 -87.710559  16.0    6      9   1.0
# 124  41.896320 -87.718782   9.0    7      9   1.0
# 125  41.896773 -87.621464  14.0    6      9   1.0
# 126  41.897032 -87.664139   4.0    6      9   1.0
# 127  41.898922 -87.731959  16.0   30      8   1.0
# 128  41.898979 -87.677140  23.0    6      9   1.0
# 129  41.899206 -87.705506  16.0   13      1   1.0
# 130  41.899477 -87.726209  11.0    6      9   1.0
# 131  41.901740 -87.679661   1.0    7      9   1.0
# 132  41.903133 -87.680459  20.0    6      9   1.0
# 133  41.903169 -87.678467   0.0    3      7   1.0
# 134  41.905992 -87.678376   2.0    6      9   1.0
# 135  41.906508 -87.679796  16.0    6      9   1.0
# 116  41.887771 -87.644305  11.0    7      9   1.0
# 114  41.887328 -87.758161  17.0    6      9   1.0
# 137  41.909463 -87.758770  19.0    6      9   1.0
# 113  41.886069 -87.766722   0.0    6      9   1.0

# %%
# Create a map centered at an average location
map_center = [crime_data['Latitude'].mean(), crime_data['Longitude'].mean()]
crime_map = folium.Map(location=map_center, zoom_start=12)

# Add markers for high-risk areas
for _, row in high_risk_areas.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"Predicted Risk: {row['pred']:.2f}\nTime: {row['Hour']}:00, Day: {row['Day']}, Month: {row['Month']}",
        icon=folium.Icon(color='red')
    ).add_to(crime_map)

# Save the map as an HTML file
crime_map.save('predicted_high_risk_areas_map.html')

# %% [markdown]
# ## Risk Assessment:
#
# Assess the risk of different areas and times for specific types of crimes to help in resource allocation for law enforcement.

# %%
y_pred_prob = tree.predict_proba(X_test_scaled)[:, 1]

# %%
X_test['pred_prob'] = y_pred_prob

# %%
risk_assessment = X_test.groupby(['Latitude','Longitude', 'Hour', 'Day', 'Month']).agg({'pred_prob': 'mean'}).reset_index()
# Identify high-risk areas and times
high_risk_areas = risk_assessment.sort_values(by='pred_prob', ascending=False).head(25)  # Top 25 high-risk areas
print(high_risk_areas)
# Out:
#       Latitude  Longitude  Hour  Day  Month  pred_prob
# 0    41.654834 -87.607558  13.0    1      9        0.0
# 115  41.887522 -87.624553  20.0    6      9        0.0
# 117  41.890674 -87.685786  15.0    5      9        0.0
# 118  41.891119 -87.686707  20.0    6      9        0.0
# 119  41.892570 -87.622058  13.0    6      9        0.0
# 120  41.895014 -87.675741  18.0    6      9        0.0
# 121  41.895409 -87.753167   8.0   29      8        0.0
# 122  41.895450 -87.653585   8.0    6      9        0.0
# 123  41.895515 -87.710559  16.0    6      9        0.0
# 124  41.896320 -87.718782   9.0    7      9        0.0
# 125  41.896773 -87.621464  14.0    6      9        0.0
# 126  41.897032 -87.664139   4.0    6      9        0.0
# 127  41.898922 -87.731959  16.0   30      8        0.0
# 128  41.898979 -87.677140  23.0    6      9        0.0
# 129  41.899206 -87.705506  16.0   13      1        0.0
# 130  41.899477 -87.726209  11.0    6      9        0.0
# 131  41.901740 -87.679661   1.0    7      9        0.0
# 132  41.903133 -87.680459  20.0    6      9        0.0
# 133  41.903169 -87.678467   0.0    3      7        0.0
# 134  41.905992 -87.678376   2.0    6      9        0.0
# 135  41.906508 -87.679796  16.0    6      9        0.0
# 116  41.887771 -87.644305  11.0    7      9        0.0
# 114  41.887328 -87.758161  17.0    6      9        0.0
# 137  41.909463 -87.758770  19.0    6      9        0.0
# 113  41.886069 -87.766722   0.0    6      9        0.0

# %%
# Create a map centered at an average location
map_center = [crime_data['Latitude'].mean(), crime_data['Longitude'].mean()]
crime_map = folium.Map(location=map_center, zoom_start=12)

# Add markers for high-risk areas
for _, row in high_risk_areas.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"Risk Score: {row['pred_prob']:.2f}\nTime: {row['Hour']}:00, Day: {row['Day']}, Month: {row['Month']}",
        icon=folium.Icon(color='red')
    ).add_to(crime_map)

# Save the map as an HTML file
crime_map.save('high_risk_areas_map.html')
